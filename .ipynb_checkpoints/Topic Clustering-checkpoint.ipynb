# %%
import pandas as pd
from chart_studio import plotly 
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import plotly.offline as offline
from nltk.corpus import stopwords
from string import punctuation
import numpy as np
# from gensim import corpora, models, similarities
from nltk.tokenize import word_tokenize

# %%
# !pip install -U gensim
# Out:
# Collecting gensim
#   Using cached gensim-3.8.3-cp36-cp36m-win_amd64.whl (24.2 MB)
# Requirement already satisfied, skipping upgrade: smart-open>=1.8.1 in c:\programdata\anaconda3\lib\site-packages (from gensim) (2.1.1)
# Requirement already satisfied, skipping upgrade: scipy>=0.18.1 in c:\programdata\anaconda3\lib\site-packages (from gensim) (1.1.0)
# Requirement already satisfied, skipping upgrade: six>=1.5.0 in c:\programdata\anaconda3\lib\site-packages (from gensim) (1.11.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.3 in c:\programdata\anaconda3\lib\site-packages (from gensim) (1.14.3)
# Collecting Cython==0.29.14
#   Using cached Cython-0.29.14-cp36-cp36m-win_amd64.whl (1.7 MB)
# Requirement already satisfied, skipping upgrade: boto3 in c:\programdata\anaconda3\lib\site-packages (from smart-open>=1.8.1->gensim) (1.14.56)
# Requirement already satisfied, skipping upgrade: requests in c:\programdata\anaconda3\lib\site-packages (from smart-open>=1.8.1->gensim) (2.18.4)
# Requirement already satisfied, skipping upgrade: boto in c:\programdata\anaconda3\lib\site-packages (from smart-open>=1.8.1->gensim) (2.48.0)
# Requirement already satisfied, skipping upgrade: jmespath<1.0.0,>=0.7.1 in c:\programdata\anaconda3\lib\site-packages (from boto3->smart-open>=1.8.1->gensim) (0.10.0)
# Requirement already satisfied, skipping upgrade: s3transfer<0.4.0,>=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from boto3->smart-open>=1.8.1->gensim) (0.3.3)
# Requirement already satisfied, skipping upgrade: botocore<1.18.0,>=1.17.56 in c:\programdata\anaconda3\lib\site-packages (from boto3->smart-open>=1.8.1->gensim) (1.17.56)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<2.7,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (2.6)
# Requirement already satisfied, skipping upgrade: urllib3<1.23,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (1.22)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (2018.11.29)
# Requirement already satisfied, skipping upgrade: python-dateutil<3.0.0,>=2.1 in c:\programdata\anaconda3\lib\site-packages (from botocore<1.18.0,>=1.17.56->boto3->smart-open>=1.8.1->gensim) (2.7.3)
# Requirement already satisfied, skipping upgrade: docutils<0.16,>=0.10 in c:\programdata\anaconda3\lib\site-packages (from botocore<1.18.0,>=1.17.56->boto3->smart-open>=1.8.1->gensim) (0.14)
# Installing collected packages: Cython, gensim
#   Attempting uninstall: Cython
#     Found existing installation: Cython 0.28.2
#     Uninstalling Cython-0.28.2:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] Access is denied: 'c:\\programdata\\anaconda3\\lib\\site-packages\\__pycache__\\cython.cpython-36.pyc'
# Consider using the `--user` option or check the permissions.

# %%
# !pip --version

# %% [markdown]
# # Import Data

# %%
dataset = pd.read_csv('Data/ForTopicClustering.csv')

# %%
AllTweets = dataset[['Text', 'Date']]
AllTweets
# Out:
#                                                     Text  \
# 0      Man I tried. I had a gal lined up to join Mili...
# 1      My grandmother requires 24/7 supervision due t...
# 2      I know a doctor who told me that the flu shot ...
# 3      They are doing an intervention for an obese wo...
# 4      I cry too, my 92 year old mum with advanced de...
# 5      Now that covid has killed my mom I am going to...
# 6      I see that "zero Covid strategy" is now the bu...
# 7      This shows the best analysis of the actual imp...
# 8      When they did get cases, they stopped all visi...
# 9                  this is me because of COVID dementia
line.iplot(fig)
# Out:
# <div>
#
#
#             <div id="92451d65-910c-4d73-b29e-c63fddf5e02a" class="plotly-graph-div" style="height:450px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("92451d65-910c-4d73-b29e-c63fddf5e02a")) {
#                     Plotly.newPlot(
#                         '92451d65-910c-4d73-b29e-c63fddf5e02a',
#                         [{"marker": {"color": "blue"}, "opacity": 0.75, "type": "histogram", "x": ["2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00:00:00", "2020-09-03T00 ...

# %% [markdown]
# # Plot Count of Tweets/Month

# %%
plt.figure(figsize=(20,10))
AllTweets['Year-Month'] = [x[:-3] for x in AllTweets['Time']]
AllTweets.groupby(['Year-Month'])['Year-Month'].count().plot(kind='bar', color='g')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# plotly.offline.init_notebook_mode()
tweetsT = pd.to_datetime(AllTweets['Year-Month'], format='%Y-%m')
# tweetsT = AllTweets['Time']

trace = go.Histogram(
    x=tweetsT,
    marker=dict(
        color='blue'
    ),
    opacity=0.75
)

layout = go.Layout(
    title='Tweet Activity Over Months',
    height=450,
    width=1000,
    xaxis=dict(
        title='Month and year'
    ),
    yaxis=dict(
        title='Tweet Quantity'
    ),
    bargap=0.2,
)

data = [trace]

fig = go.Figure(data=data, layout=layout)
offline.iplot(fig)
# Out:
# <div>
#
#
#             <div id="2fe1ae58-f295-46e9-9b8e-8fce8c5a0896" class="plotly-graph-div" style="height:450px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2fe1ae58-f295-46e9-9b8e-8fce8c5a0896")) {
#                     Plotly.newPlot(
#                         '2fe1ae58-f295-46e9-9b8e-8fce8c5a0896',
#                         [{"marker": {"color": "blue"}, "opacity": 0.75, "type": "histogram", "x": ["2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00:00:00", "2020-09-01T00 ...

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Remove duplicate tweets

# %%
print(len(AllTweets))
AllTweets.drop_duplicates(['Text'], inplace=True)
print(len(AllTweets))
# Out:
# 14849
# 14849
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
http.iloc[ 8  , : ]['Text']
# Out:
# 'The passing of ‘Fresno’s icon’: Hall of Famer Tom Seaver dies from dementia, COVID-19 https://trib.al/DZfEFEh'

# %% [markdown]
# ## Lowercase the tweets

# %%
AllTweets['Text'] = [x.lower() for x in AllTweets['Text']]
AllTweets
# Out:
#                                                     Text  \
# 0      man i tried. i had a gal lined up to join mili...
# 1      my grandmother requires 24/7 supervision due t...
# 2      i know a doctor who told me that the flu shot ...
# 3      they are doing an intervention for an obese wo...
# 4      i cry too, my 92 year old mum with advanced de...
# 5      now that covid has killed my mom i am going to...
# 6      i see that "zero covid strategy" is now the bu...
# 7      this shows the best analysis of the actual imp...
# 8      when they did get cases, they stopped all visi...
# 9                  this is me because of covid dementia
# 10     no that information is incorrect. the uk has l...
# 11     how exactly has a vet’s job changed since covi...
# 12     it’s actually the normal way of recording deat...
# 13     take a look at cd’s table 3 and you will see t...
# 14     @billgates has pledged to give away 2/3 of his...
# 15     depends on the comorbidities. when i see them ...
# 16     he’s always been stupid. now sadly he’s stupid...
# 17     my friends nan had dementia for ages and she w...
# 18     our loved ones bring thrown out their covid fr...
# 19     might help them not get dementia but gonna do ...
# 20     no just "exposed" to covid so quarantine is ne...
# 21     still working 40 hours a week in a care home. ...
# 22     watched another heart breaking story of dement...
# 23     zero covid, but a few hundred thousand deaths ...
# 24     it's about labor unions. you know the thing th...
# 25     my mum received the covid virus as a free gift...
# 14825  2020-02-24 20:25:36+00:00
# 14826  2020-02-24 08:37:29+00:00
# 14827  2020-02-24 05:18:55+00:00
# 14828  2020-02-24 04:23:29+00:00
# 14829  2020-02-21 00:16:47+00:00
# 14830  2020-02-20 10:07:39+00:00
# 14831  2020-02-18 20:51:20+00:00
# 14832  2020-02-18 18:07:59+00:00
# 14833  2020-02-16 15:33:41+00:00
# 14834  2020-02-15 01:58:40+00:00
# 14835  2020-02-13 00:19:10+00:00
# 14836  2020-02-11 05:20:25+00:00
# 14837  2020-02-06 03:30:21+00:00
# 14838  2020-02-05 10:08:43+00:00
# 14839  2020-02-04 16:21:12+00:00
# 14840  2020-02-02 12:50:23+00:00
# 14841  2020-02-02 11:55:06+00:00
# 14842  2020-01-30 15:51:05+00:00
# 14843  2020-01-30 09:57:25+00:00
# 14844  2020-01-30 03:25:57+00:00
# 14845  2020-01-28 19:15:11+00:00
# 14846  2020-01-26 22:51:58+00:00
# 14847  2020-01-26 19:02:03+00:00
# 14848  2020-01-23 17:30:26+00:00
#
# [14849 rows x 2 columns]

# %% [markdown]
# # Remove stopwords and punctuation

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Mahsa\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
corpus = AllTweets['Text'].tolist()
tokenizer = nltk.RegexpTokenizer(r"\w+")
# nopunc = tokenizer.tokenize(raw_text)
# word_tokens = word_tokenize(AllTweets['Text'].tolist()[0])
# word_tokens
# text = word_tokenize("The quick brown fox jumps over the lazy dog")
# text
numbers = '1234567890'
stoplist = stopwords.words('english') + list(punctuation) + list(numbers)

texts = [[word for word in tokenizer.tokenize(str(document)) if word not in stoplist] for document in corpus]

# %%
texts[8]
# Out:
# ['get',
#  'cases',
#  'stopped',
#  'visits',
#  'including',
#  'via',
#  'window',
#  'mom',
#  'dementia',
#  'advanced',
#  'full',
#  'month',
#  'visits',
#  'get',
#  'words',
#  'largely',
#  'oblivious',
#  'seriousness',
#  'covid',
#  'thinks',
#  'leave']

# %%
AllTweets['Text'].tolist()[8]
# Out:
# 'when they did get cases, they stopped all visits, including via window. mom’s dementia has advanced. that was about a full month of no visits. she doesn’t get more than a few words out. she’s largely oblivious to the seriousness of covid and thinks she’ll leave.'

# %%
word_tokens = word_tokenize(AllTweets['Text'].tolist()[8])
word_tokens
# Out:
# ['when',
#  'they',
#  'did',
#  'get',
#  'cases',
#  ',',
#  'they',
#  'stopped',
#  'all',
#  'visits',
#  ',',
#  'including',
#  'via',
#  'window',
#  '.',
#  'mom',
#  '’',
#  's',
#  'dementia',
#  'has',
#  'advanced',
#  '.',
#  'that',
#  'was',
#  'about',
#  'a',
#  'full',
#  'month',
#  'of',
#  'no',
#  'visits',
#  '.',
#  'she',
#  'doesn',
#  '’',
#  't',
#  'get',
#  'more',
#  'than',
#  'a',
#  'few',
#  'words',
#  'out',
#  '.',
#  'she',
#  '’',
#  's',
#  'largely',
#  'oblivious',
#  'to',
#  'the',
#  'seriousness',
#  'of',
#  'covid',
#  'and',
#  'thinks',
#  'she',
#  '’',
#  'll',
#  'leave',
#  '.']

# %%
word_tokens = tokenizer.tokenize(AllTweets['Text'].tolist()[8])
word_tokens
# Out:
# ['when',
#  'they',
#  'did',
#  'get',
#  'cases',
#  'they',
#  'stopped',
#  'all',
#  'visits',
#  'including',
#  'via',
#  'window',
#  'mom',
#  's',
#  'dementia',
#  'has',
#  'advanced',
#  'that',
#  'was',
#  'about',
#  'a',
#  'full',
#  'month',
#  'of',
#  'no',
#  'visits',
#  'she',
#  'doesn',
#  't',
#  'get',
#  'more',
#  'than',
#  'a',
#  'few',
#  'words',
#  'out',
#  'she',
#  's',
#  'largely',
#  'oblivious',
#  'to',
#  'the',
#  'seriousness',
#  'of',
#  'covid',
#  'and',
#  'thinks',
#  'she',
#  'll',
#  'leave']

# %%
corpus
# Out:
# ['man i tried. i had a gal lined up to join military intelligence then covid hit, they delayed her enlistment, her army nurse sister talked her out of it. so i’m chipping in to help her finish her bsn while she works at a dementia care facility. she’ll be an amazing nurse i’m sure.',
#  "my grandmother requires 24/7 supervision due to her dementia. the healthcare worker who is supposed to assist this evening just got back from out of state travel to a large funeral. the coordinating care facility's response to our concern is that you can catch covid anywhere. 🙄",
#  'i know a doctor who told me that the flu shot causes dementia. and, if we let them jab us once for covid, this allowance could turn into a mandated, yearly, adult vaccine.',
#  'they are doing an intervention for an obese women that covid would love to invade and a senior with dementia. how did the intervention work out @richhiggins_dc ?',
#  'i cry too, my 92 year old mum with advanced dementia, i’ve not seen since sept. my family terrified she catches covid in her nursing home. grateful people keep her safe so that she can see out her days safely and comfortably. see a different perspective and get off your soap box ',
#  'now that covid has killed my mom i am going to be nasty to these people. she lived in assisted living and hadn’t been outside in 2 years bc of dementia and these asswipes have killed her',
#  'i see that "zero covid strategy" is now the buzz phrase we all need to fap ourselves silly over. maybe when we also employ a "zero cancer", "zero heart disease", "zero dementia" and "zero suicide" strategy alongside it, i\'ll start taking you idiots seriously... #zerocovid',
#  'this shows the best analysis of the actual impact of the “lockdown” and how much worse it has been than the actual covid victims in deaths (minus alzheimer’s/dementia despair deaths), so with that added it would be even more! ',
#  'when they did get cases, they stopped all visits, including via window. mom’s dementia has advanced. that was about a full month of no visits. she doesn’t get more than a few words out. she’s largely oblivious to the seriousness of covid and thinks she’ll leave.',
#  'this is me because of covid dementia ',
#  'no that information is incorrect. the uk has labelled covid as present on death certificates that have been cited towards the 190k deaths in the eu area. these people have died from cancers, accidents, dementia, heart attacks, strokes, falls etc etc but covid has been present.',
#  'how exactly has a vet’s job changed since covid came into play? where’s the heroism exactly?',
#  'it’s actually the normal way of recording deaths. they can put several contributions on a certificate. don’t know why they count deaths as covid with simply a mention though. this was highlighted a few years ago with dementia appearing on so many certificates but not direct cause',
#  'take a look at cd’s table 3 and you will see that those conditions like “rhinal falure”, “late stage dementia”, etc would have killed them w/o covid. also, if died in car accident, but tested positive, it’s counted as covid death 🤦\u200d♀️',
#  '@billgates has pledged to give away 2/3 of his wealth during his lifetime. he is largely responsible for the eradication of polio and is currently trying to do the same for dementia, malaria and covid-19. do we hate him to?',
#  'depends on the comorbidities. when i see them adding in alzheimers and vascular dementia i call foul my dad technically died of pneumonia but it was because his alzheimers made him forget how to cough if you are in cardiac arrest or heart failure you are in danger, covid or not',
#  'he’s always been stupid. now sadly he’s stupid with dementia. reading is fundamental!',
#  'my friends nan had dementia for ages and she was put down as a covid death?',
#  'our loved ones bring thrown out their covid free homes into possible covid risk homes becaus @lpoolcouncil are closing 2 new build emi dementia homes less than 1 yr old. government needs to step in',
#  'might help them not get dementia but gonna do f all for covid 😂',
#  'no just "exposed" to covid so quarantine is necessary. they wouldn\'t want to add covid on top of dementia.',
#  'still working 40 hours a week in a care home. the residents with dementia i care for still can’t see their families. still trying to make sure your granny doesn’t die of covid. still fuming at everyone blatantly hosting house parties 🙃',
#  'watched another heart breaking story of dementia  and separation @stvnews caused by covid restrictions. it’s not even about indoor  and outdoor visiting, it’s about closeness and touch. why can’t i hold my mums hand with a glove on and a mask and having been tested? @scotgov @jeanef1msp',
#  'zero covid, but a few hundred thousand deaths in the uk from obesity, heart disease, the flu, cancer and dementia are just fine, yet we don’t live in daily fear of those or need to muzzle up in public for them. curious ... 🤔😷',
#  "it's about labor unions. you know the thing that you and the gop are trying to kill so you don't have to pay a living wage. shouldn't you be out trying to get covid so our economy can open? ",
#  "my mum received the covid virus as a free gift whilst on a 2 week stay in hospital with gastroenteritis, she came out far worse than she went in. don't know of anyone else who has had the virus only a family friend who died through dementia but his death certificate states covid",
#  'facts: such claims misrepresent the data. a death isn’t excluded from the covid-19 tally just because the person was obese or had diabetes or dementia. someone with heart problems can still be killed by covid-19, and the death certificate could mention both as contributing',
#  "really cross to be told my mum - dementia and diabetes- still can't have her foot appt (cancelled at start of lockdown) as surgery only allowed 15 min appts to reduce covid risk. a hair appt takes longer and that's seen as ok. no logic to what's allowed.",
#  '“they require care for all their waking hours, and often supervision when asleep. “the covid-19 pandemic has been a huge ordeal for people with dementia. the loss of routine and social contacts under lockdown have hastened cognitive decline” ',
#  "or live alone with dementia and all the trouble i have. i can't even drive myself to a doctor. i don't remember all the rules myself. i'm terrible at wearing a mask. someone pointed out i had it inside out at the covid testing place. im gonna die, i hope. im tired of life.",
#  'a.) he didn’t have any “assault” rifles. b.) considering his circumstances, betting he felt alone with no help. mom dies. caregiver for his father w/ dementia. covid. does not excuse his actions. but dude had a load on him.',
#  "the lives of the very elderly with underlying conditions are just as valuable as everyone else's. heart problems, cancer, dementia, etc are not highly contagious. people with heart problems, cancer, dementia, etc are particularly vulnerable to covid.",
#  'youre right actually, he decelerated our response to covid which decelerated the economy. the dementia/pedo accusation is a big time projection from the maga groupies...dude has more pics w/epstein  and  maxwell than most people have with their family.',
#  "what's chilling is cv19 is cardio-vascular as well as respiratory. it exploits (invades) rsa receptors: kidneys, heart, brain, gastro, everywhere. covid toe to almost dementia like effects. i can still crack 14+hrs sleep after 20 wks. easy.",
#  'we all see this happening. covid used as an excuse for hugely reduced services and saving money. so they are happy for cancer, dementia, diabetes, heart deaths as long as the focus is all on #coviddeaths. how huge with #lockdowndeaths become? can we start counting that data now?',
#  'care home management magazine: dementia carers supported with covid-19 care decision guide @ucl @mariecurieuk @alzheimerssoc @dementiauk #dementia #dementiacarers #carehomes',
#  '@shelaghfogarty drove 250 miles last weekend to see my dad who is in a care home with dementia . he is in last stages but had to speak to him through the window.since covid outbreak he has deteriorated and was heartbreaking to not be allowed to hug him.keep up the good work',
#  'so you’re going to cut me off because i don’t have the newest iphone? honestly? this game has gotten me through the covid physical distancing. it’s given me some peace from my moms dementia diagnosis. seriously???? come on man. so disappointed',
#  "all because of the filthy monster in our wh & gopigs in congress who don't give a damn about our frontline workers, over 900 have unnecessarily died of covid-19 while trying to save our lives. but, you know, dementia donnie is too busy golfing  and  gopigs are too busy defending it. ",
#  'months before my father-in-law was diagnosed with dementia he began to act erratically.',
#  '@nedlamont your covid regulations are killing people. my neighbor carolyn has been in convalescent homes for 2 weeks. she was admitted for dementia. nobody can visit her, she is only getting worse! it is like she is in prison, but committed no crime! stop being a tyrant! love us',
#  'multi-sensory home packs for people living with dementia. a brilliant example of arts orgs adapting creatively (as ever) to covid - get in touch with the @spare_tyre team for more info. #arts #wellbeing #health',
#  'covid-19 stress worsens dementia cases, gads says ',
#  'fauci right. the chart simply means these people had underlying conditions. they didn’t die from obesity alzheimer’s,dementia. they died from covid. these underlying conditions contributed to getting infected  and  added to severity of covid.',
#  'we too live in cornwall, with 90yr mammy on the west coast, we sometimes drive to crewe and get the train up (train all the way 13hrs!) or drive stopping overnight half way. she has alzheimer’s & dementia and is now struggling with depression due to covid. stay strong!',
#  'we have @stiralumni who says “"geron-technology” is a key aspect in the 21st century in supporting senior citizens and to achieve ageing in place, but it has challenges too, especially during covid and in people living with #dementia. learn about how we did it in hong kong."',
#  'we had planned to support hug by @laughcardiffmet through our accelerator program but due to covid we are focusing our resources on frontline services. that’s not stopping them, you can help the team bring hug to people with dementia below! ',
#  "they (@matthancock) doesn't give a toss about cancer deaths or heart attacks or strokes or dementia or car accidents or sepsis. covid gives them dictatorial powers so worth so much more.",
#  "that's terrible, i wonder how many others in the same situation, probably having to use up savings etc to survive covid. ♥️",
#  "not that i'm aware of but there ought to be. even if none is available in time for covid-19 we should learn the lessons and get prepared if only we'd had all the dementia cafes and other #community groups with techie skills we could have supported more people during this pandemic",
#  '@sdrc_research excited to hear about current landscape of dementia research and how we cope in the covid climate - challenges and opportunities ',
#  'yea.. covid can effect the brain - brain fog etc. to the extent it can even accelerate dementia..',
#  'this is such a difficult issue. mental health, particularly for those who were struggling b4 covid dementia, depression, etc. has been dealt an extremely destructive blow by the lockdown restrictions.',
#  'we need to learn to live with the risk and get on with our normal lives. the lockdown causes more problems than it solves. is covid the only illness we worry about now? cancer, dementia, depression, diabetes.....',
#  "then we're not doing too bad with the long distance, family member with cancer, another with dementia, and trying to navigate a relationship during covid/economic collapse/rise of the dumbass covid numpties. we're going to be fine. i think.",
#  "consider this, kimberly. we've got lots of evidence to suggests covid's been here since last fall. no excess deaths that you're referring to until exactly the week of the shutdowns. panic/lockdowns killed a lot of people. cancer, heart disease, dimentia patients left to die. ",
#  "hoooolleeeee shit. well, they are a private company, but...i wonder how all the ex-employees who got axed at the beginning of covid so the owners didn't have to pay their health insurance feel? wonder if any of them died?",
#  'my grandpa fell and hit his head and has been admitted to the hospital. they just called my mom to let her know he’s been fighting the nurses and keeps knocking his iv thing over. \U0001f97a he has really bad dementia and they won’t let my grandma in with him because of covid.',
#  '😂 so the $200b of increase debt doesn’t need to be paid back. do you have early stage dementia? you should get checked speaking of fear mongering, the cfrs for covid are much lower than the initial estimates that created the panic in march. most euro countries are moving on',
#  "#cafires had a text from a friend saying she's scared of a fire, won't sleep tonight. there is no fire in our area. but she's packing her important stuff. i suspect dementia, and i'd go over, but, you know, covid. puttering is good therapy, and nothing wrong with being ready. 🙁",
#  'ex. if a 93 year old grandparent passes from dementia, it’s listed as covid. also, if someone dies in a motorcycle crash, that too, is listed as covid. when family members hear that their loved ones passed from covid, two things will happen:',
#  'can’t believe nfl football is really returning this thursday. they didn’t take the proper procedures like the nba, & we can’t ignore the nyt article on racism embedded in dementia/cte claims, which will only proliferate with potential covid cases among players of diff ethnicities',
#  'look into the report circulating that only 6 % of deaths were covid realated😳😳😳😳😳',
#  "cdc august 26,2020 comorbidities 6% died from covid-19 94% had 2.6 health conditions contributing to death..ie heart, cancer, renal failure, dementia, liver disease ...that means less than 10,000 actually died exclusively from covid-19. you've been duped.",
#  'not nearly as weird as grabbing married women by the pussy and making fun of those with disabilities, while claiming to have christian values. as for dementia, not being able to drink water or walk up stairs is up there with not looking at covid deaths as a function of population',
#  'covid testing is accurate, vote by mail is trustworthy, and @joebiedein isn’t suffering from dementia ',
#  'stop being so gullible, right now people are dying because they’ve been denied treatment or had it delayed. more people die overall from dementia  and  alzheimer’s disease than from covid, and 95% of those who do had an existing health problem. this #newnormal needs to be stopped.',
#  'some people have it hard at the other extreme. my mate`s mum and dad celebrated their 70th wedding anniversary but sadly his mum succumbed to covid-19 aged 98. coping with parents with dementia cannot be easy.',
#  "i've seen a massive rise & progression in dementia in my practice since the lockdowns. deaths from dementia (not covid) jumped by 20,000 per week during max lockdowns. because lockdowns kill. when i say #openupusa it triggers people. as if they care for lives  and  i don't. silly",
#  'my mum is in a nursing home with dementia where there are covid cases. she still has hs subscription because it makes her happy. if she catches it and dies cancelling it will be one of the first things i do....',
#  'no covid testing last december, let alone covid testing that overstated positives by the amount the current tests do. there was also no reimbursement to hospitals for "covid" patients. when 92 year old dementia patients died last december, they were not covid deaths.',
#  'depending on the status of covid in your area, going to a polling place has risks. since i take care of my 78 year old dad with early dementia and heart disease and strokes, i’m not willing to risk it and will vote by mail for the first time.',
#  "of those who have died in nsw, 67 % were aged 80 or older, 24% were in their 70s, 7% were in their 60s and one person was in his 50s. pre covid we didn't spend this much on keeping the elderly alive with a mum who is suffering from dementia and now we spend billions on them ?",
#  "you're too ignorant to understand that more than 5 million people have been diagnosed with covid, several 100k, beyond the 188k that have died, have interstitial lung disease, cardiomegaly, early onset dementia and stroke. continue to be an idiot and put your family at risk.",
#  "lse and ucl study shows 26% of uk covid deaths have been of people living with dementia. god's calling to be the voice of the voiceless suggests we need to learn and make better plans for next time. supporting the weak is not negotiable. @seeofrochester",
#  'glad you know me so well. i do care, but i also care about how deaths are accounted for. dying from covid vs dying with covid are important distinctions. and if you look at excess deaths this year, the highest #’s are under dementia/alzheimer’s. nursing homes? that’s alarming.',
#  'aug 31, 2020 cdc- only 6% of reported covid-19 deaths actually have covid-19 as only cause of deaths. the rest included: cancer, heart disease, diabetes, poisoning, dementia, injury and everything else.',
#  'inundated with reports of #childabuse images, then surely that indicates scale of the problem. is this just like #elderlyabuse allow it? @clarewills9 @question2472 @nz_coco83 #saveourchildren #notonemorechild #dementia #ageing #carehomes #covidー19 #covid__19 #coronavirus',
#  'she can use all the cav luffs we can send. covid has caused aunt to have pneumonia on top. oxygen low. has dementia so even if recover dementia will have likely accelerated. also putting her on remdesivir and oxygen. momma hate being far away but even if local could not see her',
#  'you and your dementia ridden husband are the disservice to our country. he failed to form a national covid response. instead he plays golf, watches fox news and tweets all day.',
#  "like next door to me. says covid on his father's death certificate yet he died from extreme dementia and lung disease... yet tested for covid and said covid on the certificate... did covid kill him? as he had been on the way out since christmas before this deadly virus!!?",
#  '@myplace4u you are causing the deaths of americans by supporting a draft dodging lying bone spur covid denying piece of shit. by the way he is showing signs of frontal lobe dementia. which is why he went to his physicians office with secret service goons and took all his files',
#  'not just dementia patients, either. more "excess deaths" in spring 2020 due to lockdowns than due to covid. ',
#  'in britain some studies suggest dementia has been the commonest “pre-existing condition” in those dying from covid-19. many have endured the pandemic in care homes, which have accounted for nearly half of all deaths from covid-19 in the rich world. ',
#  'this was one of my fav stories we have done lately. my wife works in skilled nursing & tells me all the time how her patients have struggled since covid-19 and not seeing family. many have dementia  and  don’t understand. so happy for this couple! ❤️ ',
#  'he didn’t die from covid. he died from dementia, specifically lbs, which is a horrible disease. he just happen to test positive for covid. irresponsible headline.',
#  'deaths from dementia (not covid) jumped by 20,000 per week during max lockdowns last april. because lockdowns kill. ',
#  'feel your pain chris ,my mum had vascular dementia was sad watching her memories fade,might sound bad but i was kinda glad when in her care home covid took her before she totally forgot her memories',
#  'covid-19 is the bigger dick!',
#  "i like lyman, but he clearly assumes all excess deaths are covid. we know for a fact that isn't true b/c we've seen huge increases in alzheimers/dementia deaths. in some states the excess deaths from alzheimers/dementia alone is more than 100% of state covid deaths",
#  '#covid-19, stigma and the scandalous neglect of people living with #dementia ',
#  'i generally dislike using excess deaths as "the true covid count" because we know for a fact that alzheimer\'s and dementia deaths have soared even in places that have had low covid infections.',
#  'i believe they use the term “covid related.” if you’re 95 with dementia and you pass away with coronavirus antibodies. covid 19',
#  'just had a bit of worrying news, a member of staff at my 86 year old dementia suffering dads care home has contracted covid  and  the care home has gone into full lockdown.',
#  '4. dementia and alzheimer disease was the most common main pre-existing health condition in deaths involving covid-19 between march and june 2020 (25.6% of all deaths involving covid-19). ischaemic heart diseases were the second most common (9.9%). ',
# ...
#  'and we all know why he won\'t be "visiting" anywhere... and it isn\'t because of violence or risk of covid. this man cannot function w/out handlers  and  massive doses of dementia meds. not being mean..just stating fact.',
#  'the people with dementia and kidney failure can probably have covid removed from their death certificate.',
#  "1 dead and not from covid 19. just couldn't find more people that died from heart attacks, strokes, cancer, dementia, etc",
#  'sean, contributing causes means that covid still was the main factor in killing the now near 190000 thousand americans but that it also helped weaken the body so other things could kill it as well, this happens with people who have cancer, who have cpd, dementia etc.',
#  '...while short-staffed because so many of them also contracted covid? and my grandpa was in the dementia unit. how do you care for elderly patients w/out their full mental capacities in that situation? covid killed my grandfather.',
#  "that's not what you think it says. it's not surprising that you believe it does, but that doesn't change facts. if you have dementia and die from covid-19, you don't just invalidate the data. that's not how the real world works. that's not how science works.",
#  'my grandfather passed away in may. suffered from dementia for over a year and had had 3 open heart surgeries in past 2 years. new jersey considered him covid death. ',
#  "94% of covid deaths had contributing health conditions. 6% of cases listed from feb 1 to aug 22 are solely due to covid. the 'underlying conditions': influenza and pneumonia respiratory failure hypertension diabetes vascular dementia cardiac arrest heart failure renal failure",
#  'covid or dementia?',
#  'and i know that people with dementia frequently have weakened immune systems, but from what i have seen, dementia does not lead to an excessive weakening of the immune system, so counting people with covid and dementia as having died from dementia seems like a misleading stat.',
#  'have you checked out our #tdrablogseries? we have blog posts highlighting a variety of #research projects led by our researchers, including #research studies on potential treatments for #dementia, covid-19 research  and  care initiatives, and so much more: ',
#  'thank you to my amazing team for all that you do! 💜 #morethancare #elderly #elderlycare #seniorcare #healthcare #seniorliving #homecare #care #health #love #eldercare #dementia #family #caregiving #covid #caregiver #aging #dementiacare #alzheimers #caregivers #community #life',
#  'did you read the report? some of the underlying conditions are dementia and obesity. and we’ve known for months that people with underlying immune conditions are more susceptible to complications and more likely to die of covid.',
#  'these are not caused by covid .. dementia, hypertension, etc. ',
#  '$aktx the following are the top underlying medical conditions linked with covid-19 deaths. •influenza and pneumonia •respiratory failure •hypertensive disease •diabetes •vascular and unspecified dementia •cardiac arrest •heart failure •renal failure',
#  'counts of deaths who also tested for or suspected of having covid: accidental deaths  and  suicide - 5000 heart attack - 19500 dementia/alzheimers - 23700 cancer - 7000 sepsis - 13200 stroke - 7250 total - 75650 #6percent #covid19 #covid',
#  'my thought was more person a with dementia gets 0.1% because they were going to pass away anyways. a person in their 30s with no prior sickness 95%-100% etc. we add up all the different percentages and take the average over total deaths due to covid. what is the percentage?',
#  'for those aged 45-64 the chance of dying if you catch it is much less - something like 0.02%. in august, 239 people died with a positive covid-19 test. in the same time 12,000 will have died from cancer, 12,000 from heart disease and 40,000 from dementia. context always key',
#  "the blake family should not debase themselves to meet with dementia don. they've suffered enough -- and they don't need covid-45.",
#  'there are some categories which are obvious: dementia-- 18,497 intentional and unintentional injury, poisoning and other adverse events-- 5,133 and to list as "covid deaths" they didn\'t even have to test them-- only suspect that they also had covid.',
#  'counts of deaths who also tested for or suspected of having covid: accidental deaths  and  suicide - 5000 heart attack - 19500 dementia/alzheimers - 23700 cancer - 7000 sepsis - 13200 stroke - 7250 total - 75650',
#  "i know i've posted this before but i'm going to say it again. if there is a silver lining to covid it's insurance allowing telehealth visits for routine things. my mom is 24 hr o2 and dementia. doing her appointments for routine rx refills is so much easier with telehealth. 👍👍",
#  'the cdc listed the following as the top 5 conditions contributing to deaths where covid-19 was listed on the death certificate: ▪influenza and pneumonia ▪respiratory failure ▪hypertensive disease ▪diabetes ▪vascular and unspecified dementia @cgadamo #thebiglie',
#  'from cdc - primary causes of death -- but also tested for covid or were suspected of covid accidental deaths  and  suicide -5000 heart attack -19500 dementia/alzheimers - 23700 cancer - 7000 sepsis - 13200 stroke - 7250 total - 75650',
#  'counts of deaths who also tested for or suspected of having covid: accidental deaths  and  suicide5000 heart attack19500 dementia/alzheimers23700 cancer7000 sepsis13200 stroke7250 total75650 #covid19 #coronavirus #covid #scamdemic2020 6%',
#  "i went through the 'co-morbitiy' data - these people died from an illness & also had confirmed or suspected covid: accidental deaths  and  suicide - 5000 heart attack - 19500 dementia/alzheimers - 23700 cancer- 7000 sepsis - 13200 stroke - 7250 total - 75650 #covid19",
#  'ur a sheep my aunt died of dementia had been giving 6 months to live prior to covid . she died was tested found to have covid listed as a covid death .',
#  'sounds like you’re the only one not reading articles... covid isn’t a heart disease? what about the 6k deaths from obesity ruled as covid deaths or the 20k dementia. or the 25k from diabetes. just admit you want america to fall so the democrats have a chance this november. ',
#  'i certainly understand. my 94-year-old fil has early signs of dementia.repeats a lot of the same things,but i’m happy to listen to his stories over and  over again.growing old sucks in so many ways especially now with covid when we can’t be with our loved ones and they can’t be with us',
#  'hmm..180,000 #covid_19 deaths not accurate 🤔 can we have our lives back again? 😑 over 90% of deaths related to... hypertensive disease diabetes vascular dementia cardiac arrest heart failure renal failure intentional and unintentional injuries ',
#  'now we find out the state rejected the death certificate because the dr’s signature was not legible. back to step one, but we know now that it says dementia with no mention of covid. #covid19 is greatly underreported, dementia was exasperated by covid or she would be alive.',
#  'covid gives you influenza, chronic respiratory disease, circulatory disease, heart disease, heart attack, arrhythmia, heart failure, cerebrovascular disease, sepsis, malignant neoplasm, diabetes, obesity, alzheimers, vascular/dementia, renal failure, poisoning?',
#  'covid-19, stigma and the scandalous neglect of people living with dementia via @tc_africa',
#  'i personally know of three deaths listed as covid that the families went to fight to have that taken off their death certificate. one died from a heart attack, one from a motorcycle accident, the other from dementia. that should tell you something right there',
#  'do people still have dementia after they are dead? hermain cain’s ghost account tweeted covid isn’t fatal. someone prolly believes this too.',
#  'please pray that i can do what’s right for my mother’s fur baby. she has dementia and forgets everyone’s name but his. he is in his last few days and i can’t decide if i should put him to sleep and risk getting covid and passing it to her or waiting for him to die at home.',
#  'some of those ⬆️ could be preexisting or "with" covid. others are clearly underlying conditions, like diabetes (26k), obesity (5614), alzheimer\'s (5608), dementia (18.5k)... ...while still others are apparently deaths "with" covid rather than "from": accidents  and  suicides (~5k)',
#  'he’s got it in his dementia-addled head that cities/minorities/democrats suffer more from covid, and thinks that’s to his advantage. #livesdontmatter #winningisall',
#  'the following are the top underlying medical conditions linked with covid-19 deaths. * influenza and pneumonia * respiratory failure * hypertensive disease * diabetes * vascular and unspecified dementia * cardiac arrest * heart failure * renal failure',
#  'know anyone at risk for these? • flu/pneumonia * respiratory failure * hypertension * diabetes * vascular/unspecified dementia * cardiac arrest * heart/renal failure * injury/poisoning/adverse events then they’re at risk for covid. this is not cause to celebrate “i’m right.” ',
#  'it would have consequences beyond covid-19 and allow people to fall through the cracks. it would mean changing coronal legislation. and would skew data to a terrifying degree. residential care provide end of life care, the majority of deaths are due to dementia and are frequent',
#  '9000 otherwise healthy people with no underlying conditions died. that isn’t concerning? the others still died of covid. they just had underlying conditions that also got exacerbated. don’t act like it doesn’t matter.',
#  'and you’re aware that is listing those who’s only diagnosis was covid. so otherwise healthy people without underlying conditions. while the rest had multiple issues very likely exacerbated by covid. so they have copd and chf with covid. and then they die. it’s still of covid.',
#  'no true nurse would ever say covid attacked her dementia. if that was true it would already have been studied explicitly  and  continuing on with research. i am sorry for your heartache. may pain be replaced w/loving smiles  and  good memories soon. ',
#  'precisely. patient a has hiv, he goes to hospital & develops pneumonia. dies. patient b has had dementia for 10 years, goes to hospital, develops pneumonia. dies. pneumonia isn’t listed cause of death for either patient. but in liberal covid-19 reality, covid killed both. 🤦🏻\u200d♂️',
#  'if you read the breakdown of the comorbidities it also includes cancer, dementia, alzheimer’s, intentional and unintentional injuries, poisonings and several other causes of death that covid would not be a contributing factor.',
#  'stupid reply. explain respiratory failure, respiratory arrest, chronic respiratory disease, ards, cardiac arrest, sepsis, alzheimer’s, dementia  and  renal failure!! covid didn’t cause these deaths!!',
#  "2/ as being there. just smells & flavors are missing but my 95yr old mom just went in2 a nursing home 4 dementia when covid hit. i didn't have what it takes anymore 2 do all the things healthies demanded of me. covid stopped that.they move as slow as me now 😏kinda💞\U0001f9a0《covid",
#  '18,497 "covid" deaths were from: "vascular and unspecified dementia"',
#  'yes go down with the "5g is a way to spread covid" "there are bodies of boys in the sewage system under melbourne" brigade sam. 78 cases today and you want to start marches in the street. i thing dementia has finally got you.',
#  'ok what about all of those other comorbidities? if you have heart attack, heart failure, alzheimer’s, vascular dementia, sepsis, renal failure, or intentional and unintentional injury, poisoning and other adverse events, covid is the least of your worries.',
#  ...]

# %%
texts
# Out:
# [['man',
#   'tried',
#   'gal',
#   'lined',
#   'join',
#   'military',
#   'intelligence',
#   'covid',
#   'hit',
#   'delayed',
#   'enlistment',
#   'army',
#   'nurse',
#   'sister',
#   'talked',
#   'chipping',
#   'help',
#   'finish',
#   'bsn',
#   'works',
#   'dementia',
#   'care',
#   'facility',
#   'amazing',
#   'nurse',
#   'sure'],
#  ['grandmother',
#   'requires',
#   '24',
#   'supervision',
#   'due',
#   'dementia',
#   'healthcare',
#   'worker',
#   'supposed',
#   'assist',
#   'evening',
#   'got',
#   'back',
#   'state',
#   'travel',
#   'large',
#   'funeral',
#   'coordinating',
#   'care',
#   'facility',
#   'response',
#   'concern',
#   'catch',
#   'covid',
#   'anywhere'],
#  ['know',
#   'doctor',
#   'told',
#   'flu',
#   'shot',
#   'causes',
#   'dementia',
#   'let',
#   'jab',
#   'us',
#   'covid',
#   'allowance',
#   'could',
#   'turn',
#   'mandated',
#   'yearly',
#   'adult',
#   'vaccine'],
#  ['intervention',
#   'obese',
#   'women',
#   'covid',
#   'would',
#   'love',
#   'invade',
#   'senior',
#   'dementia',
#   'intervention',
#   'work',
#   'richhiggins_dc'],
#  ['cry',
#   '92',
#   'year',
#   'old',
#   'mum',
#   'advanced',
#   'dementia',
#   'seen',
#   'since',
#   'sept',
#   'family',
#   'terrified',
#   'catches',
#   'covid',
#   'nursing',
#   'home',
#   'grateful',
#   'people',
#   'keep',
#   'safe',
#   'see',
#   'days',
#   'safely',
#   'comfortably',
#   'see',
#   'different',
#   'perspective',
#   'get',
#   'soap',
#   'box'],
#  ['covid',
#   'killed',
#   'mom',
#   'going',
#   'nasty',
#   'people',
#   'lived',
#   'assisted',
#   'living',
#   'outside',
#   'years',
#   'bc',
#   'dementia',
#   'asswipes',
#   'killed'],
#  ['see',
#   'zero',
#   'covid',
#   'strategy',
#   'buzz',
#   'phrase',
#   'need',
#   'fap',
#   'silly',
#   'maybe',
#   'also',
#   'employ',
#   'zero',
#   'cancer',
#   'zero',
#   'heart',
#   'disease',
#   'zero',
#   'dementia',
#   'zero',
#   'suicide',
#   'strategy',
#   'alongside',
#   'start',
#   'taking',
#   'idiots',
#   'seriously',
#   'zerocovid'],
#  ['shows',
#   'best',
#   'analysis',
#   'actual',
#   'impact',
#   'lockdown',
#   'much',
#   'worse',
#   'actual',
#   'covid',
#   'victims',
#   'deaths',
#   'minus',
#   'alzheimer',
#   'dementia',
#   'despair',
#   'deaths',
#   'added',
#   'would',
#   'even'],
#  ['get',
#   'cases',
#   'stopped',
#   'visits',
#   'including',
#   'via',
#   'window',
#   'mom',
#   'dementia',
#   'advanced',
#   'full',
#   'month',
#   'visits',
#   'get',
#   'words',
#   'largely',
#   'oblivious',
#   'seriousness',
#   'covid',
#   'thinks',
#   'leave'],
#  ['covid', 'dementia'],
#  ['information',
#   'incorrect',
#   'uk',
#   'labelled',
#   'covid',
#   'present',
#   'death',
#   'certificates',
#   'cited',
#   'towards',
#   '190k',
#   'deaths',
#   'eu',
#   'area',
#   'people',
#   'died',
#   'cancers',
#   'accidents',
#   'dementia',
#   'heart',
#   'attacks',
#   'strokes',
#   'falls',
#   'etc',
#   'etc',
#   'covid',
#   'present'],
#  ['exactly',
#   'vet',
#   'job',
#   'changed',
#   'since',
#   'covid',
#   'came',
#   'play',
#   'heroism',
#   'exactly'],
#  ['actually',
#   'normal',
#   'way',
#   'recording',
#   'deaths',
#   'put',
#   'several',
#   'contributions',
#   'certificate',
#   'know',
#   'count',
#   'deaths',
#   'covid',
#   'simply',
#   'mention',
#   'though',
#   'highlighted',
#   'years',
#   'ago',
#   'dementia',
#   'appearing',
#   'many',
#   'certificates',
#   'direct',
#   'cause'],
#  ['take',
#   'look',
#   'cd',
#   'table',
#   'see',
#   'conditions',
#   'like',
#   'rhinal',
#   'falure',
#   'late',
#   'stage',
#   'dementia',
#   'etc',
#   'would',
#   'killed',
#   'w',
#   'covid',
#   'also',
#   'died',
#   'car',
#   'accident',
#   'tested',
#   'positive',
#   'counted',
#   'covid',
#   'death'],
#  ['billgates',
#   'pledged',
#   'give',
#   'away',
#   'wealth',
#   'lifetime',
#   'largely',
#   'responsible',
#   'eradication',
#   'polio',
#   'currently',
#   'trying',
#   'dementia',
#   'malaria',
#   'covid',
#   '19',
#   'hate'],
#  ['depends',
#   'comorbidities',
#   'see',
#   'adding',
#   'alzheimers',
#   'vascular',
#   'dementia',
#   'call',
#   'foul',
#   'dad',
#   'technically',
#   'died',
#   'pneumonia',
#   'alzheimers',
#   'made',
#   'forget',
#   'cough',
#   'cardiac',
#   'arrest',
#   'heart',
#   'failure',
#   'danger',
#   'covid'],
#  ['always', 'stupid', 'sadly', 'stupid', 'dementia', 'reading', 'fundamental'],
#  ['friends', 'nan', 'dementia', 'ages', 'put', 'covid', 'death'],
#  ['loved',
#   'ones',
#   'bring',
#   'thrown',
#   'covid',
#   'free',
#   'homes',
#   'possible',
#   'covid',
#   'risk',
#   'homes',
#   'becaus',
#   'lpoolcouncil',
#   'closing',
#   'new',
#   'build',
#   'emi',
#   'dementia',
#   'homes',
#   'less',
#   'yr',
#   'old',
#   'government',
#   'needs',
#   'step'],
#  ['might', 'help', 'get', 'dementia', 'gonna', 'f', 'covid'],
#  ['exposed',
#   'covid',
#   'quarantine',
#   'necessary',
#   'want',
#   'add',
#   'covid',
#   'top',
#   'dementia'],
#  ['still',
#   'working',
#   '40',
#   'hours',
#   'week',
#   'care',
#   'home',
#   'residents',
#   'dementia',
#   'care',
#   'still',
#   'see',
#   'families',
#   'still',
#   'trying',
#   'make',
#   'sure',
#   'granny',
#   'die',
#   'covid',
#   'still',
#   'fuming',
#   'everyone',
#   'blatantly',
#   'hosting',
#   'house',
#   'parties'],
#  ['watched',
#   'another',
#   'heart',
#   'breaking',
#   'story',
#   'dementia',
#   'separation',
#   'stvnews',
#   'caused',
#   'covid',
#   'restrictions',
#   'even',
#   'indoor',
#   'outdoor',
#   'visiting',
#   'closeness',
#   'touch',
#   'hold',
#   'mums',
#   'hand',
#   'glove',
#   'mask',
#   'tested',
#   'scotgov',
#   'jeanef1msp'],
#  ['zero',
#   'covid',
#   'hundred',
#   'thousand',
#   'deaths',
#   'uk',
#   'obesity',
#   'heart',
#   'disease',
#   'flu',
#   'cancer',
#   'dementia',
#   'fine',
#   'yet',
#   'live',
#   'daily',
#   'fear',
#   'need',
#   'muzzle',
#   'public',
#   'curious'],
#  ['labor',
#   'unions',
#   'know',
#   'thing',
#   'gop',
#   'trying',
#   'kill',
#   'pay',
#   'living',
#   'wage',
#   'trying',
#   'get',
#   'covid',
#   'economy',
#   'open'],
#  ['mum',
#   'received',
#   'covid',
#   'virus',
#   'free',
#   'gift',
#   'whilst',
#   'week',
#   'stay',
#   'hospital',
#   'gastroenteritis',
#   'came',
#   'far',
#   'worse',
#   'went',
#   'know',
#   'anyone',
#   'else',
#   'virus',
#   'family',
#   'friend',
#   'died',
#   'dementia',
#   'death',
#   'certificate',
#   'states',
#   'covid'],
#  ['facts',
#   'claims',
#   'misrepresent',
#   'data',
#   'death',
#   'excluded',
#   'covid',
#   '19',
#   'tally',
#   'person',
#   'obese',
#   'diabetes',
#   'dementia',
#   'someone',
#   'heart',
#   'problems',
#   'still',
#   'killed',
#   'covid',
#   '19',
#   'death',
#   'certificate',
#   'could',
#   'mention',
#   'contributing'],
#  ['really',
#   'cross',
#   'told',
#   'mum',
#   'dementia',
#   'diabetes',
#   'still',
#   'foot',
#   'appt',
#   'cancelled',
#   'start',
#   'lockdown',
#   'surgery',
#   'allowed',
#   '15',
#   'min',
#   'appts',
#   'reduce',
#   'covid',
#   'risk',
#   'hair',
#   'appt',
#   'takes',
#   'longer',
#   'seen',
#   'ok',
#   'logic',
#   'allowed'],
#  ['require',
#   'care',
#   'waking',
#   'hours',
#   'often',
#   'supervision',
#   'asleep',
#   'covid',
#   '19',
#   'pandemic',
#   'huge',
#   'ordeal',
#   'people',
#   'dementia',
#   'loss',
#   'routine',
#   'social',
#   'contacts',
#   'lockdown',
#   'hastened',
#   'cognitive',
#   'decline'],
#  ['live',
#   'alone',
#   'dementia',
#   'trouble',
#   'even',
#   'drive',
#   'doctor',
#   'remember',
#   'rules',
#   'terrible',
#   'wearing',
#   'mask',
#   'someone',
#   'pointed',
#   'inside',
#   'covid',
#   'testing',
#   'place',
#   'im',
#   'gonna',
#   'die',
#   'hope',
#   'im',
#   'tired',
#   'life'],
#  ['assault',
#   'rifles',
#   'b',
#   'considering',
#   'circumstances',
#   'betting',
#   'felt',
#   'alone',
#   'help',
#   'mom',
#   'dies',
#   'caregiver',
#   'father',
#   'w',
#   'dementia',
#   'covid',
#   'excuse',
#   'actions',
#   'dude',
#   'load'],
#  ['lives',
#   'elderly',
#   'underlying',
#   'conditions',
#   'valuable',
#   'everyone',
#   'else',
#   'heart',
#   'problems',
#   'cancer',
#   'dementia',
#   'etc',
#   'highly',
#   'contagious',
#   'people',
#   'heart',
#   'problems',
#   'cancer',
#   'dementia',
#   'etc',
#   'particularly',
#   'vulnerable',
#   'covid'],
#  ['youre',
#   'right',
#   'actually',
#   'decelerated',
#   'response',
#   'covid',
#   'decelerated',
#   'economy',
#   'dementia',
#   'pedo',
#   'accusation',
#   'big',
#   'time',
#   'projection',
#   'maga',
#   'groupies',
#   'dude',
#   'pics',
#   'w',
#   'epstein',
#   'maxwell',
#   'people',
#   'family'],
#  ['chilling',
#   'cv19',
#   'cardio',
#   'vascular',
#   'well',
#   'respiratory',
#   'exploits',
#   'invades',
#   'rsa',
#   'receptors',
#   'kidneys',
#   'heart',
#   'brain',
#   'gastro',
#   'everywhere',
#   'covid',
#   'toe',
#   'almost',
#   'dementia',
#   'like',
#   'effects',
#   'still',
#   'crack',
#   '14',
#   'hrs',
#   'sleep',
#   '20',
#   'wks',
#   'easy'],
#  ['see',
#   'happening',
#   'covid',
#   'used',
#   'excuse',
#   'hugely',
#   'reduced',
#   'services',
#   'saving',
#   'money',
#   'happy',
#   'cancer',
#   'dementia',
#   'diabetes',
#   'heart',
#   'deaths',
#   'long',
#   'focus',
#   'coviddeaths',
#   'huge',
#   'lockdowndeaths',
#   'become',
#   'start',
#   'counting',
#   'data'],
#  ['care',
#   'home',
#   'management',
#   'magazine',
#   'dementia',
#   'carers',
#   'supported',
#   'covid',
#   '19',
#   'care',
#   'decision',
#   'guide',
#   'ucl',
#   'mariecurieuk',
#   'alzheimerssoc',
#   'dementiauk',
#   'dementia',
#   'dementiacarers',
#   'carehomes'],
#  ['shelaghfogarty',
#   'drove',
#   '250',
#   'miles',
#   'last',
#   'weekend',
#   'see',
#   'dad',
#   'care',
#   'home',
#   'dementia',
#   'last',
#   'stages',
#   'speak',
#   'window',
#   'since',
#   'covid',
#   'outbreak',
#   'deteriorated',
#   'heartbreaking',
#   'allowed',
#   'hug',
#   'keep',
#   'good',
#   'work'],
#  ['going',
#   'cut',
#   'newest',
#   'iphone',
#   'honestly',
#   'game',
#   'gotten',
#   'covid',
#   'physical',
#   'distancing',
#   'given',
#   'peace',
#   'moms',
#   'dementia',
#   'diagnosis',
#   'seriously',
#   'come',
#   'man',
#   'disappointed'],
#  ['filthy',
#   'monster',
#   'wh',
#   'gopigs',
#   'congress',
#   'give',
#   'damn',
#   'frontline',
#   'workers',
#   '900',
#   'unnecessarily',
#   'died',
#   'covid',
#   '19',
#   'trying',
#   'save',
#   'lives',
#   'know',
#   'dementia',
#   'donnie',
#   'busy',
#   'golfing',
#   'gopigs',
#   'busy',
#   'defending'],
#  ['months',
#   'father',
#   'law',
#   'diagnosed',
#   'dementia',
#   'began',
#   'act',
#   'erratically'],
#  ['nedlamont',
#   'covid',
#   'regulations',
#   'killing',
#   'people',
#   'neighbor',
#   'carolyn',
#   'convalescent',
#   'homes',
#   'weeks',
#   'admitted',
#   'dementia',
#   'nobody',
#   'visit',
#   'getting',
#   'worse',
#   'like',
#   'prison',
#   'committed',
#   'crime',
#   'stop',
#   'tyrant',
#   'love',
#   'us'],
#  ['multi',
#   'sensory',
#   'home',
#   'packs',
#   'people',
#   'living',
#   'dementia',
#   'brilliant',
#   'example',
#   'arts',
#   'orgs',
#   'adapting',
#   'creatively',
#   'ever',
#   'covid',
#   'get',
#   'touch',
#   'spare_tyre',
#   'team',
#   'info',
#   'arts',
#   'wellbeing',
#   'health'],
#  ['covid', '19', 'stress', 'worsens', 'dementia', 'cases', 'gads', 'says'],
#  ['fauci',
#   'right',
#   'chart',
#   'simply',
#   'means',
#   'people',
#   'underlying',
#   'conditions',
#   'die',
#   'obesity',
#   'alzheimer',
#   'dementia',
#   'died',
#   'covid',
#   'underlying',
#   'conditions',
#   'contributed',
#   'getting',
#   'infected',
#   'added',
#   'severity',
#   'covid'],
#  ['live',
#   'cornwall',
#   '90yr',
#   'mammy',
#   'west',
#   'coast',
#   'sometimes',
#   'drive',
#   'crewe',
#   'get',
#   'train',
#   'train',
#   'way',
#   '13hrs',
#   'drive',
#   'stopping',
#   'overnight',
#   'half',
#   'way',
#   'alzheimer',
#   'dementia',
#   'struggling',
#   'depression',
#   'due',
#   'covid',
#   'stay',
#   'strong'],
#  ['stiralumni',
#   'says',
#   'geron',
#   'technology',
#   'key',
#   'aspect',
#   '21st',
#   'century',
#   'supporting',
#   'senior',
#   'citizens',
#   'achieve',
#   'ageing',
#   'place',
#   'challenges',
#   'especially',
#   'covid',
#   'people',
#   'living',
#   'dementia',
#   'learn',
#   'hong',
#   'kong'],
#  ['planned',
#   'support',
#   'hug',
#   'laughcardiffmet',
#   'accelerator',
#   'program',
#   'due',
#   'covid',
#   'focusing',
#   'resources',
#   'frontline',
#   'services',
#   'stopping',
#   'help',
#   'team',
#   'bring',
#   'hug',
#   'people',
#   'dementia'],
#  ['matthancock',
#   'give',
#   'toss',
#   'cancer',
#   'deaths',
#   'heart',
#   'attacks',
#   'strokes',
#   'dementia',
#   'car',
#   'accidents',
#   'sepsis',
#   'covid',
#   'gives',
#   'dictatorial',
#   'powers',
#   'worth',
#   'much'],
#  ['terrible',
#   'wonder',
#   'many',
#   'others',
#   'situation',
#   'probably',
#   'use',
#   'savings',
#   'etc',
#   'survive',
#   'covid'],
#  ['aware',
#   'ought',
#   'even',
#   'none',
#   'available',
#   'time',
#   'covid',
#   '19',
#   'learn',
#   'lessons',
#   'get',
#   'prepared',
#   'dementia',
#   'cafes',
#   'community',
#   'groups',
#   'techie',
#   'skills',
#   'could',
#   'supported',
#   'people',
#   'pandemic'],
#  ['sdrc_research',
#   'excited',
#   'hear',
#   'current',
#   'landscape',
#   'dementia',
#   'research',
#   'cope',
#   'covid',
#   'climate',
#   'challenges',
#   'opportunities'],
#  ['yea',
#   'covid',
#   'effect',
#   'brain',
#   'brain',
#   'fog',
#   'etc',
#   'extent',
#   'even',
#   'accelerate',
#   'dementia'],
#  ['difficult',
#   'issue',
#   'mental',
#   'health',
#   'particularly',
#   'struggling',
#   'b4',
#   'covid',
#   'dementia',
#   'depression',
#   'etc',
#   'dealt',
#   'extremely',
#   'destructive',
#   'blow',
#   'lockdown',
#   'restrictions'],
#  ['need',
#   'learn',
#   'live',
#   'risk',
#   'get',
#   'normal',
#   'lives',
#   'lockdown',
#   'causes',
#   'problems',
#   'solves',
#   'covid',
#   'illness',
#   'worry',
#   'cancer',
#   'dementia',
#   'depression',
#   'diabetes'],
#  ['bad',
#   'long',
#   'distance',
#   'family',
#   'member',
#   'cancer',
#   'another',
#   'dementia',
#   'trying',
#   'navigate',
#   'relationship',
#   'covid',
#   'economic',
#   'collapse',
#   'rise',
#   'dumbass',
#   'covid',
#   'numpties',
#   'going',
#   'fine',
#   'think'],
#  ['consider',
#   'kimberly',
#   'got',
#   'lots',
#   'evidence',
#   'suggests',
#   'covid',
#   'since',
#   'last',
#   'fall',
#   'excess',
#   'deaths',
#   'referring',
#   'exactly',
#   'week',
#   'shutdowns',
#   'panic',
#   'lockdowns',
#   'killed',
#   'lot',
#   'people',
#   'cancer',
#   'heart',
#   'disease',
#   'dimentia',
#   'patients',
#   'left',
#   'die'],
#  ['hoooolleeeee',
#   'shit',
#   'well',
#   'private',
#   'company',
#   'wonder',
#   'ex',
#   'employees',
#   'got',
#   'axed',
#   'beginning',
#   'covid',
#   'owners',
#   'pay',
#   'health',
#   'insurance',
#   'feel',
#   'wonder',
#   'died'],
#  ['grandpa',
#   'fell',
#   'hit',
#   'head',
#   'admitted',
#   'hospital',
#   'called',
#   'mom',
#   'let',
#   'know',
#   'fighting',
#   'nurses',
#   'keeps',
#   'knocking',
#   'iv',
#   'thing',
#   'really',
#   'bad',
#   'dementia',
#   'let',
#   'grandma',
#   'covid'],
#  ['200b',
#   'increase',
#   'debt',
#   'need',
#   'paid',
#   'back',
#   'early',
#   'stage',
#   'dementia',
#   'get',
#   'checked',
#   'speaking',
#   'fear',
#   'mongering',
#   'cfrs',
#   'covid',
#   'much',
#   'lower',
#   'initial',
#   'estimates',
#   'created',
#   'panic',
#   'march',
#   'euro',
#   'countries',
#   'moving'],
#  ['cafires',
#   'text',
#   'friend',
#   'saying',
#   'scared',
#   'fire',
#   'sleep',
#   'tonight',
#   'fire',
#   'area',
#   'packing',
#   'important',
#   'stuff',
#   'suspect',
#   'dementia',
#   'go',
#   'know',
#   'covid',
#   'puttering',
#   'good',
#   'therapy',
#   'nothing',
#   'wrong',
#   'ready'],
#  ['ex',
#   '93',
#   'year',
#   'old',
#   'grandparent',
#   'passes',
#   'dementia',
#   'listed',
#   'covid',
#   'also',
#   'someone',
#   'dies',
#   'motorcycle',
#   'crash',
#   'listed',
#   'covid',
#   'family',
#   'members',
#   'hear',
#   'loved',
#   'ones',
#   'passed',
#   'covid',
#   'two',
#   'things',
#   'happen'],
#  ['believe',
#   'nfl',
#   'football',
#   'really',
#   'returning',
#   'thursday',
#   'take',
#   'proper',
#   'procedures',
#   'like',
#   'nba',
#   'ignore',
#   'nyt',
#   'article',
#   'racism',
#   'embedded',
#   'dementia',
#   'cte',
#   'claims',
#   'proliferate',
#   'potential',
#   'covid',
#   'cases',
#   'among',
#   'players',
#   'diff',
#   'ethnicities'],
#  ['look', 'report', 'circulating', 'deaths', 'covid', 'realated'],
#  ['cdc',
#   'august',
#   '26',
#   '2020',
#   'comorbidities',
#   'died',
#   'covid',
#   '19',
#   '94',
#   'health',
#   'conditions',
#   'contributing',
#   'death',
#   'ie',
#   'heart',
#   'cancer',
#   'renal',
#   'failure',
#   'dementia',
#   'liver',
#   'disease',
#   'means',
#   'less',
#   '10',
#   '000',
#   'actually',
#   'died',
#   'exclusively',
#   'covid',
#   '19',
#   'duped'],
#  ['nearly',
#   'weird',
#   'grabbing',
#   'married',
#   'women',
#   'pussy',
#   'making',
#   'fun',
#   'disabilities',
#   'claiming',
#   'christian',
#   'values',
#   'dementia',
#   'able',
#   'drink',
#   'water',
#   'walk',
#   'stairs',
#   'looking',
#   'covid',
#   'deaths',
#   'function',
#   'population'],
#  ['covid',
#   'testing',
#   'accurate',
#   'vote',
#   'mail',
#   'trustworthy',
#   'joebiedein',
#   'suffering',
#   'dementia'],
#  ['stop',
#   'gullible',
#   'right',
#   'people',
#   'dying',
#   'denied',
#   'treatment',
#   'delayed',
#   'people',
#   'die',
#   'overall',
#   'dementia',
#   'alzheimer',
#   'disease',
#   'covid',
#   '95',
#   'existing',
#   'health',
#   'problem',
#   'newnormal',
#   'needs',
#   'stopped'],
#  ['people',
#   'hard',
#   'extreme',
#   'mate',
#   'mum',
#   'dad',
#   'celebrated',
#   '70th',
#   'wedding',
#   'anniversary',
#   'sadly',
#   'mum',
#   'succumbed',
#   'covid',
#   '19',
#   'aged',
#   '98',
#   'coping',
#   'parents',
#   'dementia',
#   'cannot',
#   'easy'],
#  ['seen',
#   'massive',
#   'rise',
#   'progression',
#   'dementia',
#   'practice',
#   'since',
#   'lockdowns',
#   'deaths',
#   'dementia',
#   'covid',
#   'jumped',
#   '20',
#   '000',
#   'per',
#   'week',
#   'max',
#   'lockdowns',
#   'lockdowns',
#   'kill',
#   'say',
#   'openupusa',
#   'triggers',
#   'people',
#   'care',
#   'lives',
#   'silly'],
#  ['mum',
#   'nursing',
#   'home',
#   'dementia',
#   'covid',
#   'cases',
#   'still',
#   'hs',
#   'subscription',
#   'makes',
#   'happy',
#   'catches',
#   'dies',
#   'cancelling',
#   'one',
#   'first',
#   'things'],
#  ['covid',
#   'testing',
#   'last',
#   'december',
#   'let',
#   'alone',
#   'covid',
#   'testing',
#   'overstated',
#   'positives',
#   'amount',
#   'current',
#   'tests',
#   'also',
#   'reimbursement',
#   'hospitals',
#   'covid',
#   'patients',
#   '92',
#   'year',
#   'old',
#   'dementia',
#   'patients',
#   'died',
#   'last',
#   'december',
#   'covid',
#   'deaths'],
#  ['depending',
#   'status',
#   'covid',
#   'area',
#   'going',
#   'polling',
#   'place',
#   'risks',
#   'since',
#   'take',
#   'care',
#   '78',
#   'year',
#   'old',
#   'dad',
#   'early',
#   'dementia',
#   'heart',
#   'disease',
#   'strokes',
#   'willing',
#   'risk',
#   'vote',
#   'mail',
#   'first',
#   'time'],
#  ['died',
#   'nsw',
#   '67',
#   'aged',
#   '80',
#   'older',
#   '24',
#   '70s',
#   '60s',
#   'one',
#   'person',
#   '50s',
#   'pre',
#   'covid',
#   'spend',
#   'much',
#   'keeping',
#   'elderly',
#   'alive',
#   'mum',
#   'suffering',
#   'dementia',
#   'spend',
#   'billions'],
#  ['ignorant',
#   'understand',
#   'million',
#   'people',
#   'diagnosed',
#   'covid',
#   'several',
#   '100k',
#   'beyond',
#   '188k',
#   'died',
#   'interstitial',
#   'lung',
#   'disease',
#   'cardiomegaly',
#   'early',
#   'onset',
#   'dementia',
#   'stroke',
#   'continue',
#   'idiot',
#   'put',
#   'family',
#   'risk'],
#  ['unfair',
#   'papaw',
#   'alzheimers',
#   'dementia',
#   'covid',
#   'restrictions',
#   'hard',
#   'mamaw',
#   'yesterday',
#   '56th',
#   'anniversary',
#   'spend'],
#  ['sympathise',
#   'mother',
#   'law',
#   'care',
#   'home',
#   'stop',
#   'visits',
#   'visitors',
#   'disobeyed',
#   'rules',
#   'new',
#   'cases',
#   'covid',
#   'also',
#   'suffers',
#   'dementia',
#   'problem',
#   'visitors',
#   'cared',
#   'family',
#   'members',
#   'residents',
#   'staff'],
#  ['large',
#   'covid',
#   'deaths',
#   'pointed',
#   'inept',
#   'dementia',
#   'democrat',
#   'governors'],
#  ['competence',
#   'yes',
#   'incompetent',
#   'ever',
#   'gained',
#   'bc',
#   'dementia',
#   'way',
#   'street',
#   'effective',
#   'sociopath',
#   'exacting',
#   'vengeance',
#   'destroying',
#   'america',
#   'competent',
#   '1mm',
#   'ppl',
#   'dead',
#   'covid'],
#  ['based',
#   'risk',
#   'assessment',
#   'family',
#   'member',
#   'full',
#   'ppe',
#   'visit',
#   'top',
#   'floor',
#   'see',
#   'loved',
#   'one',
#   'resident',
#   'might',
#   'distressed',
#   'due',
#   'covid',
#   'restrictions',
#   'even',
#   'missing',
#   'families',
#   'negative',
#   'effect',
#   'staff',
#   'full',
#   'ppe',
#   'residents',
#   'dementia',
#   'beyond',
#   'words'],
#  ['think',
#   'saying',
#   'debating',
#   'counting',
#   'dementia',
#   'deaths',
#   'among',
#   'lockdown',
#   'deaths',
#   'due',
#   'lockdown',
#   'due',
#   'covid'],
#  ['hard',
#   'separate',
#   'sure',
#   'nursing',
#   'homes',
#   'want',
#   'admit',
#   'isolation',
#   'neglect',
#   'killed',
#   'people',
#   'one',
#   'going',
#   'fight',
#   'say',
#   'covid',
#   'instead',
#   'one',
#   'checking',
#   'verifying',
#   'yes',
#   'isolation',
#   'kill',
#   'dementia',
#   'patient',
#   'short',
#   'order'],
#  ['detest',
#   'johnson',
#   'cohort',
#   'every',
#   'fibre',
#   'stay',
#   'home',
#   'ever',
#   'covid',
#   'stay',
#   'along',
#   'aids',
#   'polio',
#   'cancer',
#   'dementia',
#   'etc',
#   'etc',
#   'life',
#   'lottery',
#   'live',
#   'uk',
#   'winning',
#   'ticket',
#   'syria',
#   'less'],
#  ['cannot',
#   'wait',
#   'welcome',
#   'amazing',
#   'wellbeing_auks',
#   'members',
#   'back',
#   'lost',
#   'dear',
#   'beloved',
#   'extended',
#   'family',
#   'members',
#   'living',
#   'care',
#   'homes',
#   'covid',
#   'lost',
#   'far',
#   'social',
#   'death',
#   'people',
#   'dementia',
#   'experienced',
#   'pandemic'],
#  ['would',
#   'help',
#   'paying',
#   'medical',
#   'bills',
#   'dad',
#   'suffers',
#   'dementia',
#   'covid',
#   'things',
#   'challenging'],
#  ['well',
#   'read',
#   'statistic',
#   'died',
#   'via',
#   'covid',
#   'flu',
#   'jab',
#   'gov',
#   'web',
#   'site',
#   'flu',
#   'jab',
#   'evil',
#   'eventually',
#   'cause',
#   'brain',
#   'problems',
#   'like',
#   'alzheimer',
#   'dementia',
#   'etc',
#   'metals'],
#  ['son',
#   'chd',
#   'masks',
#   'classroom',
#   'concern',
#   'health',
#   'work',
#   'dementia',
#   'care',
#   'home',
#   'covid',
#   'free',
#   'throughout',
#   'could',
#   'ruined',
#   'kids',
#   'wearing',
#   'masks',
#   'like',
#   'job',
#   'covid2019',
#   'protectourchildren',
#   'wearamask'],
#  ['old',
#   'covid',
#   'still',
#   'takes',
#   'nothing',
#   'away',
#   'intent',
#   'argument',
#   'guy',
#   'thinks',
#   'hide',
#   'behind',
#   'dead',
#   'son',
#   'mislead',
#   'people',
#   'keep',
#   'asked',
#   'questions',
#   'really',
#   'blame',
#   'dementia',
#   'sure',
#   'remember',
#   'shit',
#   'anyways'],
#  ['appears', 'dementia'],
#  ['memory',
#   'hole',
#   'rising',
#   'prevalence',
#   'dementia',
#   'global',
#   'emergency',
#   'covid',
#   'going',
#   'impact',
#   'much'],
#  ['agree',
#   'devastation',
#   'covid',
#   'goes',
#   'beyond',
#   'virus',
#   'mental',
#   'health',
#   'important',
#   'especially',
#   'residence',
#   'dementia',
#   'also',
#   'anyone',
#   'feels',
#   'cut',
#   'outside',
#   'world'],
#  ['loved',
#   'ones',
#   'turned',
#   'dementia',
#   'care',
#   'homes',
#   'covid',
#   'crisis',
#   'presumably',
#   'crappy',
#   'contracts'],
#  ['jeremy_hunt',
#   'years',
#   'ago',
#   'charge',
#   'promises',
#   'made',
#   'dementia',
#   'sufferers',
#   'period',
#   'ran',
#   'new',
#   'continued',
#   'iniatives',
#   'attending',
#   'funerals',
#   'covid',
#   'human',
#   'beings',
#   'important',
#   'years',
#   'ago'],
#  ['happening',
#   'lose',
#   'saying',
#   '150',
#   'million',
#   'covid',
#   'sorry',
#   'health',
#   'obvious',
#   'dementia'],
#  ['oh',
#   'opposed',
#   'impeachment',
#   'based',
#   'dumb',
#   'ukraine',
#   'chat',
#   '100',
#   'grand',
#   'russian',
#   'facebook',
#   'ads',
#   'covid',
#   'killing',
#   'billions',
#   '87',
#   'year',
#   'olds',
#   'dementia'],
#  ['got',
#   'phone',
#   'w',
#   'aunt',
#   'mothers',
#   'sister',
#   'dementia',
#   'currently',
#   'battlin',
#   'covid',
#   'hearing',
#   'voice',
#   'crushed',
#   'stay',
#   'phone',
#   'tears',
#   'poring',
#   'face',
#   'didnt',
#   'want',
#   'hear',
#   'sobs',
#   'already',
#   'lost',
#   'two',
#   'family',
#   'members',
#   'year',
#   '2020',
#   'sigh'],
#  ['craigslist',
#   'bdrm',
#   'exchange',
#   'part',
#   'time',
#   'care',
#   'elderly',
#   'person',
#   'w',
#   'dementia',
#   'get',
#   'bathroom',
#   'dress',
#   'breakfast',
#   'reqs',
#   'references',
#   'background',
#   'credit',
#   'mature',
#   'responsible',
#   'caring',
#   'car',
#   'req',
#   'licensure',
#   'anything',
#   'covid',
#   'many',
#   'thoughts'],
#  ['run', 'dementia', 'laden', 'fossil', 'dems', 'put', 'forth'],
#  ['average',
#   'age',
#   'congress',
#   '125',
#   'almost',
#   'suffer',
#   'dementia',
#   'tds',
#   'etc',
#   'covid',
#   'wiped'],
#  ['wow',
#   'open',
#   'eyes',
#   'even',
#   'going',
#   'nominee',
#   'coming',
#   'puppet',
#   'right',
#   'changing',
#   'views',
#   'saying',
#   'controlled',
#   'say',
#   'switcheroo',
#   'coming',
#   'planned',
#   'covid',
#   'dementia',
#   'excuse'],
#  ['really',
#   'bad',
#   'day',
#   'watch',
#   'tv',
#   'read',
#   'three',
#   'weeks',
#   'since',
#   'became',
#   'unwell',
#   'two',
#   'weeks',
#   'received',
#   'positive',
#   'result',
#   'covid',
#   'believe',
#   'looking',
#   'mum',
#   'dementia',
#   'special',
#   'needs',
#   'brother',
#   'whilst',
#   'covid'],
#  ['cases',
#   'covid',
#   'either',
#   'homes',
#   'people',
#   'dementia',
#   'complex',
#   'nursing',
#   'needs',
#   'closed',
#   'less',
#   'year',
#   'lpoolcouncil',
#   '17m',
#   'investment',
#   'week',
#   'eviction',
#   'notice',
#   'millvina',
#   'brushwood',
#   'donotbelieveaword',
#   'becausewecare',
#   'theirvoice',
#   'please',
#   'help'],
#  ['u', 'k', '31', 'covid', 'deaths', 'dementia', '92', 'total', 'comorbidity'],
#  ['recycled',
#   'campaign',
#   '2016',
#   'covid',
#   '19',
#   'botched',
#   'response',
#   'military',
#   'scandal',
#   'dementia',
#   'tests',
#   'mini',
#   'strokes',
#   'thing',
#   'surging',
#   'bile',
#   'almost',
#   'see',
#   'turn',
#   'yellow',
#   'orange'],
#  ['neighbors',
#   'father',
#   'advanced',
#   'dementia',
#   'verge',
#   'death',
#   'due',
#   'organs',
#   'shutting',
#   'day',
#   'perhaps',
#   'two',
#   'death',
#   'certificate',
#   'states',
#   'died',
#   'covid',
#   'hearing',
#   'similar',
#   'stories',
#   'around',
#   'country',
#   'real',
#   'count',
#   'needs',
#   'investigated'],
#  ['people',
#   'died',
#   'covid',
#   'somehow',
#   'precious',
#   'died',
#   'cancelled',
#   'cancer',
#   'operations',
#   'tb',
#   'dementia',
#   'sent',
#   'away',
#   'die',
#   'empty',
#   'hospitals'],
#  ['indigo6e',
#   'seeking',
#   'refund',
#   'tickets',
#   'travel',
#   'period',
#   'covid',
#   '19',
#   'lockdown',
#   'passengers',
#   'high',
#   'risk',
#   'cancer',
#   'survivor',
#   '64',
#   'dementia',
#   'patient',
#   '72',
#   'years',
#   'old',
#   'kid',
#   'year',
#   'old',
#   'kid',
#   'put',
#   'life',
#   'danger',
#   'recover',
#   'money',
#   'plz',
#   'show',
#   'humanity'],
#  ['ask',
#   'part',
#   'advocating',
#   'people',
#   'circumstances',
#   'well',
#   'dangerous',
#   'conditions',
#   'heart',
#   'disease',
#   'strokes',
#   'dementia',
#   'etc',
#   'sets',
#   'anxiety',
#   'denying',
#   'covid',
#   'asking',
#   'badly',
#   'needed',
#   'perspective'],
#  ['u',
#   'k',
#   'relative',
#   'dementia',
#   'upset',
#   'confused',
#   'could',
#   'see',
#   'family',
#   'wife',
#   'went',
#   'along',
#   'rules',
#   'died',
#   'anyway',
#   'covid',
#   '50',
#   'years',
#   'seeing',
#   'every',
#   'day',
#   'last',
#   'months',
#   'alone',
#   'go',
#   'see',
#   'relatives',
#   'late',
#   'fight'],
#  ['fuck',
#   'feb',
#   'march',
#   'grandad',
#   '80',
#   'old',
#   'folks',
#   'dementia',
#   'room',
#   'killed',
#   'covid',
#   'useless',
#   'unprepared',
#   'fucking',
#   'late',
#   'fuck',
#   'head'],
#  ['ever',
#   'crucial',
#   'keep',
#   'talking',
#   'dementia',
#   'ensure',
#   'dementia',
#   'remains',
#   'priority',
#   'covid',
#   '19',
#   'letstalkaboutdementia',
#   'worldalzmonth'],
#  ['2021', 'dies', 'covid', '20', 'complicated', 'dementia'],
#  ['think',
#   'means',
#   'quite',
#   'often',
#   'people',
#   'allowed',
#   'die',
#   'many',
#   'probably',
#   'best',
#   'interests',
#   'could',
#   'saved',
#   'including',
#   '82',
#   'year',
#   'old',
#   'best',
#   'mates',
#   'grandpa',
#   'person',
#   'know',
#   'died',
#   'covid',
#   'severe',
#   'dementia'],
#  ['spot',
#   'paramedic',
#   'wife',
#   'gown',
#   'hilt',
#   'help',
#   'heart',
#   'disease',
#   'dementia',
#   'patients',
#   'seen',
#   'first',
#   'hand',
#   'efforts',
#   'covid',
#   '19',
#   'fearful',
#   'catching',
#   'passing',
#   'us',
#   'family',
#   'welch',
#   'madeley',
#   'keep',
#   'ignorance'],
#  ['dementia',
#   'part',
#   'sociopath',
#   'hoped',
#   'would',
#   'mentally',
#   'collapse',
#   'existential',
#   'crisis',
#   'arrived',
#   'case',
#   'covid',
#   '19',
#   'think',
#   'white',
#   'house',
#   'staff',
#   'propped',
#   'never',
#   'folded'],
#  ['may',
#   'dementia',
#   'heart',
#   'issues',
#   'emphysema',
#   'however',
#   'covid',
#   'would',
#   'likely',
#   'still',
#   'called',
#   'causation',
#   'another',
#   'concept',
#   'seem',
#   'grasp'],
#  ['jesus',
#   'christ',
#   'andrew',
#   'disgusting',
#   'human',
#   'visited',
#   'many',
#   'people',
#   'interact',
#   'dementia',
#   'varying',
#   'degrees',
#   'humanity',
#   'lost',
#   'people',
#   'like',
#   'andrew',
#   'appalling',
#   'covid',
#   'stop',
#   'us',
#   'interacting',
#   'loved',
#   'ones'],
#  ['dementia',
#   'heart',
#   'disease',
#   'hospitalize',
#   'get',
#   'sick',
#   'go',
#   'hospital',
#   'die',
#   'covid',
#   'thems',
#   'rules',
#   'thanks',
#   'heads',
#   'dr',
#   'cristina'],
#  ['person',
#   '55',
#   'likely',
#   'die',
#   'bath',
#   'covid',
#   'yet',
#   'business',
#   'almost',
#   'entirely',
#   'sacrificed',
#   'mother',
#   'cannot',
#   'get',
#   'care',
#   'assistance',
#   'dementia',
#   'diagnosis',
#   'delayed',
#   'since',
#   'mar',
#   'appointments',
#   'cancelled',
#   'ridiculous'],
#  ['constituent',
#   'itu',
#   'nurse',
#   'cared',
#   'covid',
#   'patients',
#   'petrifying',
#   'peak',
#   'pandemic',
#   'want',
#   'help',
#   'visit',
#   'mum',
#   'dementia',
#   'care',
#   'home',
#   'dies'],
#  ['would',
#   'love',
#   'know',
#   'dementia',
#   'sufferers',
#   'covid',
#   'death',
#   'numbers',
#   'wonderful',
#   'thing',
#   'cohort',
#   'one',
#   'believes',
#   'word',
#   'say',
#   'speak',
#   'non',
#   'family',
#   'sometimes',
#   'family',
#   'tend',
#   'think',
#   'cruel',
#   'prolong',
#   'lives'],
#  ['90',
#   'covid',
#   'deaths',
#   '80',
#   'dementia',
#   'patients',
#   'patients',
#   'multiple',
#   'health',
#   'issues',
#   'suggesting',
#   'allow',
#   'covid19',
#   'dementia',
#   'patients',
#   'dont',
#   'count',
#   'lives',
#   'count',
#   'tally',
#   'worthiness'],
#  ['friends',
#   'father',
#   'passed',
#   'recently',
#   'aged',
#   'care',
#   'allowed',
#   'visits',
#   'family',
#   'tested',
#   'every',
#   'three',
#   'days',
#   'alone',
#   'barely',
#   'spoke',
#   'english',
#   'tested',
#   'positive',
#   'eventually',
#   'died',
#   'neglect',
#   'freaking',
#   'covid',
#   '84',
#   'dementia',
#   'sick',
#   'stuff'],
#  ['dan',
#   'say',
#   'elimination',
#   'impossible',
#   'presser',
#   'eg',
#   'covid',
#   'patients',
#   'like',
#   'aged',
#   'dementia',
#   'patient',
#   'help',
#   'contact',
#   'tracing'],
#  ['man',
#   'dementia',
#   'fighting',
#   'thinks',
#   'killing',
#   'babies',
#   'okay',
#   'kamala',
#   'much',
#   'po',
#   'supports',
#   'worry',
#   'covid',
#   'babies',
#   'killed',
#   'hypocrite'],
#  ['asked',
#   'understand',
#   'pressure',
#   'mit',
#   'professor',
#   'covid',
#   'climate',
#   'never',
#   'asked',
#   'position',
#   'mother',
#   'died',
#   'covid19',
#   'father',
#   'post',
#   'covid',
#   'dementia',
#   'ci',
#   'interest',
#   'rate',
#   'top',
#   'concern',
#   'foh',
#   'human',
#   'first',
#   'profs'],
#  ['mom',
#   'home',
#   'dementia',
#   'drs',
#   'said',
#   'b',
#   'held',
#   'elder',
#   'abuse',
#   'let',
#   'go',
#   'back',
#   'home',
#   'disabled',
#   'put',
#   'place',
#   'liked',
#   'even',
#   'unpacked',
#   'covid',
#   'hit',
#   'mar',
#   'everything',
#   'locked',
#   'seen',
#   'since',
#   'opened',
#   'aug',
#   'outside',
#   'hot'],
#  ['fractured',
#   'pelvis',
#   'kill',
#   'puts',
#   'bed',
#   'month',
#   'lung',
#   'spaces',
#   'collapse',
#   'significantly',
#   'increase',
#   'pneumonia',
#   'risk',
#   'dementia',
#   'increases',
#   'risks',
#   'plus',
#   'age',
#   'ie',
#   'one',
#   'led',
#   'another',
#   'pelvis',
#   'kill',
#   'tony',
#   'covid'],
#  ['godmother',
#   'mother',
#   'care',
#   'home',
#   'one',
#   'specialises',
#   'providing',
#   'care',
#   'people',
#   'dementia',
#   'covid',
#   '19',
#   'went',
#   'tearing',
#   'people',
#   '90s',
#   'like',
#   'died',
#   'know',
#   'elderly',
#   'deaths',
#   'count'],
#  ['cancer',
#   'treated',
#   'good',
#   'potential',
#   'outcomes',
#   'get',
#   'covid',
#   'die',
#   'killed',
#   'essentially',
#   'argument',
#   'making',
#   'dementia',
#   'get',
#   'covid',
#   'die',
#   'killed',
#   'heart',
#   'disease',
#   'get',
#   'covid',
#   'die'],
#  ['one',
#   'nz',
#   'person',
#   'day',
#   'dead',
#   'suicide',
#   'worried',
#   'covid',
#   '90',
#   'covid',
#   'deaths',
#   '80',
#   'dementia',
#   'patients',
#   'patients',
#   'multiple',
#   'health',
#   'issues',
#   'hospitals',
#   'cancer',
#   'medical',
#   'treatment',
#   'killing',
#   'patients'],
#  ['lifafas', 'demonstrated', 'selective', 'dementia', 'covid', '19'],
#  ['okay',
#   'would',
#   'died',
#   'get',
#   'covid',
#   'difference',
#   'dad',
#   'dementia',
#   'got',
#   'pneumonia',
#   'cause',
#   'death',
#   'say',
#   'died',
#   'head',
#   'injury',
#   'list',
#   'death',
#   'cert',
#   'covid',
#   'chose',
#   'ending',
#   'case'],
#  ['know',
#   'works',
#   'much',
#   'line',
#   'know',
#   'lockdown',
#   'caused',
#   'cause',
#   'far',
#   'deaths',
#   'covid',
#   'cancer',
#   'dementia',
#   'deaths',
#   'already',
#   'know',
#   'rising',
#   'mental',
#   'health',
#   'suicide',
#   'homelessness',
#   'poverty',
#   'loneliness',
#   'list',
#   'goes'],
#  ['sweden',
#   'lockdown',
#   'fared',
#   'us',
#   'also',
#   'third',
#   'care',
#   'homes',
#   'better',
#   'strategy',
#   'deaths',
#   'would',
#   'reduced',
#   'lockdown',
#   'deaths',
#   'much',
#   'higher',
#   'covid',
#   'including',
#   'already',
#   'know',
#   'cancer',
#   'dementia',
#   'deaths'],
#  ['yes',
#   'vote',
#   'one',
#   'without',
#   'dementia',
#   'one',
#   'ended',
#   'wars',
#   'brought',
#   'peace',
#   'middle',
#   'east',
#   'one',
#   'cut',
#   'taxes',
#   'cares',
#   'unborn'],
#  ['sports',
#   'escape',
#   'gets',
#   'mind',
#   'stress',
#   'job',
#   'work',
#   'hospital',
#   'ever',
#   'hear',
#   'covid',
#   '19',
#   'dementia',
#   'cancer',
#   'alcoholism',
#   'name',
#   'things',
#   'need',
#   'escape',
#   'players',
#   'free',
#   'protest',
#   'kneel',
#   'whatever',
#   'want',
#   'watch',
#   'game'],
#  ['oh',
#   'also',
#   'loved',
#   'ones',
#   'dying',
#   'covid',
#   'novel',
#   'point',
#   'apparently',
#   'lol',
#   'grandmas',
#   'dying',
#   'years',
#   'dementia',
#   'barely',
#   'remembers',
#   'panic',
#   'attacks',
#   'every',
#   '30',
#   'seconds',
#   'strokes',
#   'constantly',
#   'tell',
#   'anyone',
#   'bc'],
#  ['able',
#   'see',
#   'mum',
#   'nursing',
#   'home',
#   'passed',
#   'dementia',
#   'covid',
#   '19',
#   'funeral',
#   'large',
#   'family',
#   'instead',
#   'normal',
#   'one'],
#  ['agree',
#   'totally',
#   'jeff',
#   'one',
#   'victoria',
#   'dies',
#   'issues',
#   'apart',
#   'covid',
#   '19',
#   'cancer',
#   'heart',
#   'disease',
#   'leukemia',
#   'dementia',
#   'parkinsons',
#   'influenza',
#   'many',
#   'diseases',
#   'thankfully',
#   'cured',
#   'thanks',
#   'covid',
#   'one',
#   'speaks',
#   'suicide',
#   'deaths'],
#  ['covid',
#   'virus',
#   'real',
#   'kids',
#   'sorts',
#   'shit',
#   'like',
#   'whooping',
#   'cough',
#   'mumps',
#   'chicken',
#   'pox',
#   'loads',
#   'autistic',
#   'kids',
#   'talk',
#   'one',
#   'two',
#   'know',
#   'course',
#   'called',
#   'autistic',
#   'epidemic',
#   'rate',
#   'everyones',
#   'nan',
#   'dementia'],
#  ['oh', 'boy', 'shiiit', 'thinking', 'sean', 'got', 'covid', 'dementia'],
#  ['dementia',
#   'heart',
#   'disease',
#   'highly',
#   'contagious',
#   'denise',
#   'without',
#   'current',
#   'measures',
#   'covid',
#   'would',
#   'kill',
#   'hundreds',
#   'thousands',
#   'please',
#   'stop',
#   'promoting',
#   'complete',
#   'fucking',
#   'nonsense',
#   'thanks'],
#  ['hard',
#   'understand',
#   'causes',
#   'include',
#   'poisoning',
#   'accidents',
#   'adverse',
#   'events',
#   'dementia',
#   'sepsis',
#   'cancer',
#   'heart',
#   'failure',
#   'wow',
#   'idea',
#   'covid',
#   'causes',
#   'cancer',
#   'heart',
#   'failure',
#   'mask'],
#  ['covid',
#   'virus',
#   'bad',
#   'virus',
#   'govt',
#   'far',
#   'worse',
#   'caused',
#   'increase',
#   'suicides',
#   'drug',
#   'alcohol',
#   'abuse',
#   'dementia',
#   'deaths',
#   'domestic',
#   'violence',
#   'divorce',
#   'unemployment',
#   'small',
#   'business',
#   'bankruptcy',
#   'censorship',
#   'national',
#   'debt',
#   'crony',
#   'bailouts',
#   'wealth',
#   'divide',
#   'social',
#   'unrest'],
#  ['couple',
#   'days',
#   'ago',
#   'said',
#   'tested',
#   'covid',
#   'let',
#   'guess',
#   'say',
#   'test',
#   'came',
#   'back',
#   'positive',
#   'everyone',
#   'knows',
#   'dementia'],
#  ['elderly',
#   'nys',
#   'nursing',
#   'homes',
#   'dying',
#   'isolation',
#   'covid',
#   'positivity',
#   'lt',
#   'covid',
#   'killing',
#   'cuomo',
#   'isolation',
#   'policies',
#   'isolation',
#   'killing',
#   'nursing',
#   'home',
#   'residents',
#   'every',
#   'day',
#   'dementia',
#   'failure',
#   'thrive',
#   'deaths',
#   'cuomo',
#   'policies',
#   'wrong'],
#  ['sorry',
#   'loss',
#   'beautiful',
#   'sweet',
#   'kind',
#   'mom',
#   'passed',
#   'days',
#   'ago',
#   'battling',
#   'dementia',
#   'well',
#   'disease',
#   'robs',
#   'much',
#   'difficult',
#   'time',
#   'lose',
#   'loved',
#   'one',
#   'covid',
#   'thoughts',
#   'family'],
#  ['original',
#   'tweet',
#   'explain',
#   'anything',
#   'curves',
#   'peak',
#   '10',
#   '11',
#   'april',
#   'middle',
#   'full',
#   'blown',
#   'lockdowns',
#   'supposedly',
#   'thing',
#   'causing',
#   'extra',
#   'dementia',
#   'deaths',
#   'deaths',
#   'start',
#   'going',
#   'covid',
#   'deaths',
#   'beginning',
#   'july',
#   'curves',
#   'go',
#   'tandem'],
#  ['excess', 'weight', 'may', 'increase', 'risk', 'dementia'],
#  ['says',
#   'lot',
#   'best',
#   'come',
#   'non',
#   'evidenced',
#   'accusation',
#   'dementia',
#   'sends',
#   'kids',
#   'school',
#   'patel',
#   'talking',
#   'israeli',
#   'government',
#   'williamson',
#   'leaking',
#   'secrets',
#   'governments',
#   'reporters',
#   'u',
#   'turns',
#   'covid',
#   'response',
#   'focus',
#   'abbott'],
#  ['concerned',
#   'people',
#   'health',
#   'favour',
#   'evicting',
#   '83',
#   'people',
#   'dementia',
#   'complex',
#   'nursing',
#   'needs',
#   'care',
#   'homes',
#   'requiring',
#   'improvement',
#   'pandemic',
#   'reprehensible',
#   'hypocrites',
#   'survived',
#   'covid',
#   'lpoolcouncil',
#   'see',
#   'millvina',
#   'brushwood',
#   'becausewecare'],
#  ['180',
#   '000',
#   'dead',
#   'americans',
#   'lmao',
#   '10',
#   '000',
#   'due',
#   'covid',
#   'thank',
#   '83',
#   'year',
#   'old',
#   'aunt',
#   'w',
#   'dementia',
#   'nurse',
#   'home',
#   'q',
#   'tined',
#   'since',
#   'feb',
#   'recovered',
#   'deadly',
#   'covid',
#   'three',
#   'days',
#   'election',
#   'infection'],
#  ['curve',
#   'exactly',
#   'follows',
#   'covid',
#   'cases',
#   'deaths',
#   'curve',
#   'first',
#   'sharply',
#   'middle',
#   'full',
#   'blown',
#   'lockdowns',
#   'second',
#   'wave',
#   'use',
#   'brain',
#   'covid',
#   'deaths',
#   'misclassified',
#   'dementia',
#   'deaths'],
#  ['enough',
#   'fight',
#   'cancer',
#   'heart',
#   'disease',
#   'diabetes',
#   'dementia',
#   'killed',
#   'covid',
#   'year',
#   'covid',
#   '3rd',
#   'end',
#   'year',
#   'control'],
#  ['guess',
#   'pretty',
#   'good',
#   'patients',
#   'dementia',
#   'anything',
#   'child',
#   'takes',
#   'twice',
#   'long',
#   'speak',
#   'really',
#   'clearly',
#   'slowly',
#   'times',
#   'skills',
#   'really',
#   'useful'],
#  ['lse',
#   'ucl',
#   'study',
#   'shows',
#   '26',
#   'uk',
#   'covid',
#   'deaths',
#   'people',
#   'living',
#   'dementia',
#   'god',
#   'calling',
#   'voice',
#   'voiceless',
#   'suggests',
#   'need',
#   'learn',
#   'make',
#   'better',
#   'plans',
#   'next',
#   'time',
#   'supporting',
#   'weak',
#   'negotiable',
#   'seeofrochester'],
#  ['glad',
#   'know',
#   'well',
#   'care',
#   'also',
#   'care',
#   'deaths',
#   'accounted',
#   'dying',
#   'covid',
#   'vs',
#   'dying',
#   'covid',
#   'important',
#   'distinctions',
#   'look',
#   'excess',
#   'deaths',
#   'year',
#   'highest',
#   'dementia',
#   'alzheimer',
#   'nursing',
#   'homes',
#   'alarming'],
#  ['aug',
#   '31',
#   '2020',
#   'cdc',
#   'reported',
#   'covid',
#   '19',
#   'deaths',
#   'actually',
#   'covid',
#   '19',
#   'cause',
#   'deaths',
#   'rest',
#   'included',
#   'cancer',
#   'heart',
#   'disease',
#   'diabetes',
#   'poisoning',
#   'dementia',
#   'injury',
#   'everything',
#   'else'],
#  ['inundated',
#   'reports',
#   'childabuse',
#   'images',
#   'surely',
#   'indicates',
#   'scale',
#   'problem',
#   'like',
#   'elderlyabuse',
#   'allow',
#   'clarewills9',
#   'question2472',
#   'nz_coco83',
#   'saveourchildren',
#   'notonemorechild',
#   'dementia',
#   'ageing',
#   'carehomes',
#   'covidー19',
#   'covid__19',
#   'coronavirus'],
#  ['use',
#   'cav',
#   'luffs',
#   'send',
#   'covid',
#   'caused',
#   'aunt',
#   'pneumonia',
#   'top',
#   'oxygen',
#   'low',
#   'dementia',
#   'even',
#   'recover',
#   'dementia',
#   'likely',
#   'accelerated',
#   'also',
#   'putting',
#   'remdesivir',
#   'oxygen',
#   'momma',
#   'hate',
#   'far',
#   'away',
#   'even',
#   'local',
#   'could',
#   'see'],
#  ['dementia',
#   'ridden',
#   'husband',
#   'disservice',
#   'country',
#   'failed',
#   'form',
#   'national',
#   'covid',
#   'response',
#   'instead',
#   'plays',
#   'golf',
#   'watches',
#   'fox',
#   'news',
#   'tweets',
#   'day'],
#  ['like',
#   'next',
#   'door',
#   'says',
#   'covid',
#   'father',
#   'death',
#   'certificate',
#   'yet',
#   'died',
#   'extreme',
#   'dementia',
#   'lung',
#   'disease',
#   'yet',
#   'tested',
#   'covid',
#   'said',
#   'covid',
#   'certificate',
#   'covid',
#   'kill',
#   'way',
#   'since',
#   'christmas',
#   'deadly',
#   'virus'],
#  ['myplace4u',
#   'causing',
#   'deaths',
#   'americans',
#   'supporting',
#   'draft',
#   'dodging',
#   'lying',
#   'bone',
#   'spur',
#   'covid',
#   'denying',
#   'piece',
#   'shit',
#   'way',
#   'showing',
#   'signs',
#   'frontal',
#   'lobe',
#   'dementia',
#   'went',
#   'physicians',
#   'office',
#   'secret',
#   'service',
#   'goons',
#   'took',
#   'files'],
#  ['dementia',
#   'patients',
#   'either',
#   'excess',
#   'deaths',
#   'spring',
#   '2020',
#   'due',
#   'lockdowns',
#   'due',
#   'covid'],
#  ['britain',
#   'studies',
#   'suggest',
#   'dementia',
#   'commonest',
#   'pre',
#   'existing',
#   'condition',
#   'dying',
#   'covid',
#   '19',
#   'many',
#   'endured',
#   'pandemic',
#   'care',
#   'homes',
#   'accounted',
#   'nearly',
#   'half',
#   'deaths',
#   'covid',
#   '19',
#   'rich',
#   'world'],
#  ['one',
#   'fav',
#   'stories',
#   'done',
#   'lately',
#   'wife',
#   'works',
#   'skilled',
#   'nursing',
#   'tells',
#   'time',
#   'patients',
#   'struggled',
#   'since',
#   'covid',
#   '19',
#   'seeing',
#   'family',
#   'many',
#   'dementia',
#   'understand',
#   'happy',
#   'couple'],
#  ['die',
#   'covid',
#   'died',
#   'dementia',
#   'specifically',
#   'lbs',
#   'horrible',
#   'disease',
#   'happen',
#   'test',
#   'positive',
#   'covid',
#   'irresponsible',
#   'headline'],
#  ['deaths',
#   'dementia',
#   'covid',
#   'jumped',
#   '20',
#   '000',
#   'per',
#   'week',
#   'max',
#   'lockdowns',
#   'last',
#   'april',
#   'lockdowns',
#   'kill'],
#  ['feel',
#   'pain',
#   'chris',
#   'mum',
#   'vascular',
#   'dementia',
#   'sad',
#   'watching',
#   'memories',
#   'fade',
#   'might',
#   'sound',
#   'bad',
#   'kinda',
#   'glad',
#   'care',
#   'home',
#   'covid',
#   'took',
#   'totally',
#   'forgot',
#   'memories'],
#  ['covid', '19', 'bigger', 'dick'],
#  ['like',
#   'lyman',
#   'clearly',
#   'assumes',
#   'excess',
#   'deaths',
#   'covid',
#   'know',
#   'fact',
#   'true',
#   'b',
#   'c',
#   'seen',
#   'huge',
#   'increases',
#   'alzheimers',
#   'dementia',
#   'deaths',
#   'states',
#   'excess',
#   'deaths',
#   'alzheimers',
#   'dementia',
#   'alone',
#   '100',
#   'state',
#   'covid',
#   'deaths'],
#  ['covid',
#   '19',
#   'stigma',
#   'scandalous',
#   'neglect',
#   'people',
#   'living',
#   'dementia'],
#  ['generally',
#   'dislike',
#   'using',
#   'excess',
#   'deaths',
#   'true',
#   'covid',
#   'count',
#   'know',
#   'fact',
#   'alzheimer',
#   'dementia',
#   'deaths',
#   'soared',
#   'even',
#   'places',
#   'low',
#   'covid',
#   'infections'],
#  ['believe',
#   'use',
#   'term',
#   'covid',
#   'related',
#   '95',
#   'dementia',
#   'pass',
#   'away',
#   'coronavirus',
#   'antibodies',
#   'covid',
#   '19'],
#  ['bit',
#   'worrying',
#   'news',
#   'member',
#   'staff',
#   '86',
#   'year',
#   'old',
#   'dementia',
#   'suffering',
#   'dads',
#   'care',
#   'home',
#   'contracted',
#   'covid',
#   'care',
#   'home',
#   'gone',
#   'full',
#   'lockdown'],
#  ['dementia',
#   'alzheimer',
#   'disease',
#   'common',
#   'main',
#   'pre',
#   'existing',
#   'health',
#   'condition',
#   'deaths',
#   'involving',
#   'covid',
#   '19',
#   'march',
#   'june',
#   '2020',
#   '25',
#   'deaths',
#   'involving',
#   'covid',
#   '19',
#   'ischaemic',
#   'heart',
#   'diseases',
#   'second',
#   'common'],
#  ['please',
#   'tell',
#   'lpoolcouncil',
#   'pauldbrant',
#   'mayor_anderson',
#   'let',
#   'know',
#   '83',
#   'vulnerable',
#   'dementia',
#   'victims',
#   'evicting',
#   'care',
#   'homes',
#   'oct',
#   'end',
#   'hospitals',
#   'blocking',
#   'needed',
#   'beds',
#   'pandemic',
#   'covid',
#   'members',
#   'families',
#   'also',
#   'due',
#   'stress'],
#  ['handled',
#   'poorly',
#   'government',
#   'nhs',
#   'top',
#   'suits',
#   'feel',
#   'nhs',
#   'staff',
#   'bosses',
#   'clowns',
#   'would',
#   'lived',
#   'covid',
#   'prob',
#   'copd',
#   'dementia',
#   'kidney',
#   'failure',
#   'test',
#   'covid',
#   'sent',
#   'home',
#   'die',
#   'right',
#   'lot'],
#  ['dementia',
#   'cancer',
#   'get',
#   'acute',
#   'infection',
#   'die',
#   'eg',
#   'covid',
#   'influenza',
#   'cause',
#   'death',
#   'chronic',
#   'illnesses',
#   'noted',
#   'causative'],
#  ['yet',
#   'people',
#   'want',
#   'vote',
#   '47',
#   'year',
#   'politician',
#   'shows',
#   'signs',
#   'dementia',
#   'lead',
#   'poser',
#   'permanent',
#   'funding',
#   'hbcu',
#   'prison',
#   'reform',
#   'prior',
#   'covid',
#   'lowest',
#   'unemployment',
#   'rate'],
#  ['covid',
#   'restrictions',
#   'dementia',
#   'services',
#   'could',
#   'lead',
#   'increase',
#   'nursing',
#   'home',
#   'admissions',
#   'charity',
#   'says'],
#  ['voting',
#   'man',
#   'honestly',
#   'thought',
#   '120',
#   'million',
#   'people',
#   'died',
#   'people',
#   'died',
#   'covid',
#   'two',
#   'world',
#   'wars',
#   'voting',
#   'dementia',
#   'patient'],
#  ['covid',
#   'causing',
#   'sticky',
#   'blood',
#   'blood',
#   'vessels',
#   'may',
#   'lead',
#   'future',
#   'dementia',
#   'cases',
#   'mention',
#   'strokes',
#   'heart',
#   'disease'],
#  ['speaking',
#   'old',
#   'ladies',
#   'nursing',
#   'homes',
#   'stepgrandmother',
#   'ancient',
#   'far',
#   'gone',
#   'dementia',
#   'covid',
#   'hope',
#   'cause',
#   'suffering'],
#  ['sing',
#   'killing',
#   'softly',
#   'total',
#   'care',
#   'w',
#   'dementia',
#   'covid',
#   'patient',
#   'changing',
#   'w',
#   'coworker',
#   'know',
#   'good',
#   'day'],
#  ['understand',
#   'tracks',
#   'april',
#   'spike',
#   'non',
#   'covid',
#   'fatalities',
#   'looks',
#   'like',
#   'april',
#   'covid',
#   'accelerated',
#   'dementia',
#   'deaths',
#   'lockdowns',
#   'accelerating'],
#  ['excuse',
#   'ignorance',
#   'sympathetic',
#   'trend',
#   'inverse',
#   'relationship',
#   'dad',
#   'dementia',
#   'mid',
#   '70s',
#   'die',
#   'hard',
#   'vietnam',
#   'vet',
#   'concerned',
#   'get',
#   'covid',
#   'va',
#   'va',
#   'give',
#   'hcq',
#   'prophylactic',
#   'risk',
#   'vets'],
#  ['alzheimer',
#   'dementia',
#   'trending',
#   'sympathetically',
#   'covid',
#   'death',
#   'shaped',
#   'lockdown',
#   'death',
#   'curve',
#   'deaths',
#   'appear',
#   'result',
#   'lack',
#   'services',
#   'adding',
#   'lockdown',
#   'deaths',
#   'possibly'],
#  ['hc',
#   'solved',
#   'dementia',
#   'asperger',
#   'amid',
#   'covid',
#   '19',
#   'biggest',
#   'jackpot',
#   'supposed',
#   '2017',
#   'paris',
#   'trip',
#   'via',
#   'media',
#   'cancel',
#   'due',
#   'led',
#   'drug',
#   'war',
#   'smart',
#   'child',
#   'failed',
#   'jackpot',
#   'cancel',
#   'hc',
#   'cancel',
#   'jackpot',
#   'smart',
#   'child',
#   'ac360',
#   'drsanjaygupta',
#   'donlemon',
#   'halagorani',
#   'camanpour',
#   'cnn',
#   'cnni'],
#  ['never',
#   'vote',
#   'someone',
#   'confabulates',
#   'sign',
#   'dementia',
#   'conspiracies',
#   'cruz',
#   'dad',
#   'killing',
#   'jfk',
#   'winning',
#   'popular',
#   'vote',
#   'covid',
#   '19',
#   'pandemic',
#   'prevent',
#   'reelection',
#   'mailed',
#   'voting',
#   'corrupt',
#   'spied'],
#  ['hard',
#   'able',
#   'see',
#   'mother',
#   'law',
#   'dementia',
#   'window',
#   'covid',
#   'sat',
#   'every',
#   'night',
#   'hours',
#   'went',
#   'sleep',
#   'love',
#   'lucid',
#   'moments'],
#  ['friend',
#   'dad',
#   'severe',
#   'dementia',
#   'falls',
#   'shit',
#   'time',
#   'multiple',
#   'loans',
#   'taken',
#   'name',
#   'identity',
#   'thieves',
#   'keeps',
#   'playing',
#   'along',
#   'thinks',
#   'gonna',
#   'win',
#   'back',
#   'money',
#   'owes',
#   'falling',
#   'nigerian',
#   'prince',
#   'schemes'],
#  ['coworker',
#   'mine',
#   'lost',
#   '90',
#   'yr',
#   'old',
#   'grandmother',
#   'dimentia',
#   'months',
#   'ago',
#   'tested',
#   'weekly',
#   'covid',
#   'neg',
#   'everytime',
#   'cause',
#   'death',
#   'covid',
#   'know',
#   'shocker',
#   'family',
#   'fought',
#   'changed'],
#  ['anyone',
#   'explored',
#   'idea',
#   'new',
#   'covid',
#   'expert',
#   'believes',
#   'herd',
#   'immunity',
#   'aka',
#   'genocide',
#   'radiologist',
#   'performed',
#   'midnight',
#   'cat',
#   'scan',
#   'covidiot',
#   'walter',
#   'reed',
#   'specialty',
#   'brain',
#   'spine',
#   'dementia',
#   'stroke',
#   'collateral',
#   'stroke',
#   'damage',
#   'maddow'],
#  ['well',
#   'dad',
#   'nursing',
#   'home',
#   'allowed',
#   'see',
#   'also',
#   'dementia',
#   'covid',
#   'result',
#   'death',
#   'certificate',
#   'also',
#   'bed',
#   'sores',
#   'tells',
#   'staring',
#   'ceiling',
#   'months',
#   'speak',
#   'defend'],
#  ['today',
#   'listened',
#   'tried',
#   'cry',
#   'patient',
#   'moderately',
#   'advanced',
#   'dementia',
#   'told',
#   'quarantined',
#   'covid',
#   'shattered'],
#  ['dying', 'dementia', 'sound', 'like', 'dying', 'dementia'],
#  ['nope',
#   'perfect',
#   'philosophy',
#   'live',
#   'stop',
#   'learning',
#   'stagnant',
#   'begin',
#   'regressing',
#   'block',
#   'learning',
#   'choose',
#   'delusion',
#   'reality',
#   'existence',
#   'wasted',
#   'also',
#   'leaves',
#   'susceptible',
#   'dementia',
#   'alzheimer'],
#  ['continue',
#   'sky',
#   'falling',
#   'covid',
#   'propaganda',
#   'cause',
#   'one',
#   'things',
#   'left',
# ...
#   'dementia',
#   'covid',
#   '19',
#   'research',
#   'care',
#   'initiatives',
#   'much'],
#  ['thank',
#   'amazing',
#   'team',
#   'morethancare',
#   'elderly',
#   'elderlycare',
#   'seniorcare',
#   'healthcare',
#   'seniorliving',
#   'homecare',
#   'care',
#   'health',
#   'love',
#   'eldercare',
#   'dementia',
#   'family',
#   'caregiving',
#   'covid',
#   'caregiver',
#   'aging',
#   'dementiacare',
#   'alzheimers',
#   'caregivers',
#   'community',
#   'life'],
#  ['read',
#   'report',
#   'underlying',
#   'conditions',
#   'dementia',
#   'obesity',
#   'known',
#   'months',
#   'people',
#   'underlying',
#   'immune',
#   'conditions',
#   'susceptible',
#   'complications',
#   'likely',
#   'die',
#   'covid'],
#  ['caused', 'covid', 'dementia', 'hypertension', 'etc'],
#  ['aktx',
#   'following',
#   'top',
#   'underlying',
#   'medical',
#   'conditions',
#   'linked',
#   'covid',
#   '19',
#   'deaths',
#   'influenza',
#   'pneumonia',
#   'respiratory',
#   'failure',
#   'hypertensive',
#   'disease',
#   'diabetes',
#   'vascular',
#   'unspecified',
#   'dementia',
#   'cardiac',
#   'arrest',
#   'heart',
#   'failure',
#   'renal',
#   'failure'],
#  ['counts',
#   'deaths',
#   'also',
#   'tested',
#   'suspected',
#   'covid',
#   'accidental',
#   'deaths',
#   'suicide',
#   '5000',
#   'heart',
#   'attack',
#   '19500',
#   'dementia',
#   'alzheimers',
#   '23700',
#   'cancer',
#   '7000',
#   'sepsis',
#   '13200',
#   'stroke',
#   '7250',
#   'total',
#   '75650',
#   '6percent',
#   'covid19',
#   'covid'],
#  ['thought',
#   'person',
#   'dementia',
#   'gets',
#   'going',
#   'pass',
#   'away',
#   'anyways',
#   'person',
#   '30s',
#   'prior',
#   'sickness',
#   '95',
#   '100',
#   'etc',
#   'add',
#   'different',
#   'percentages',
#   'take',
#   'average',
#   'total',
#   'deaths',
#   'due',
#   'covid',
#   'percentage'],
#  ['aged',
#   '45',
#   '64',
#   'chance',
#   'dying',
#   'catch',
#   'much',
#   'less',
#   'something',
#   'like',
#   '02',
#   'august',
#   '239',
#   'people',
#   'died',
#   'positive',
#   'covid',
#   '19',
#   'test',
#   'time',
#   '12',
#   '000',
#   'died',
#   'cancer',
#   '12',
#   '000',
#   'heart',
#   'disease',
#   '40',
#   '000',
#   'dementia',
#   'context',
#   'always',
#   'key'],
#  ['blake',
#   'family',
#   'debase',
#   'meet',
#   'dementia',
#   'suffered',
#   'enough',
#   'need',
#   'covid',
#   '45'],
#  ['categories',
#   'obvious',
#   'dementia',
#   '18',
#   '497',
#   'intentional',
#   'unintentional',
#   'injury',
#   'poisoning',
#   'adverse',
#   'events',
#   '133',
#   'list',
#   'covid',
#   'deaths',
#   'even',
#   'test',
#   'suspect',
#   'also',
#   'covid'],
#  ['counts',
#   'deaths',
#   'also',
#   'tested',
#   'suspected',
#   'covid',
#   'accidental',
#   'deaths',
#   'suicide',
#   '5000',
#   'heart',
#   'attack',
#   '19500',
#   'dementia',
#   'alzheimers',
#   '23700',
#   'cancer',
#   '7000',
#   'sepsis',
#   '13200',
#   'stroke',
#   '7250',
#   'total',
#   '75650'],
#  ['know',
#   'posted',
#   'going',
#   'say',
#   'silver',
#   'lining',
#   'covid',
#   'insurance',
#   'allowing',
#   'telehealth',
#   'visits',
#   'routine',
#   'things',
#   'mom',
#   '24',
#   'hr',
#   'o2',
#   'dementia',
#   'appointments',
#   'routine',
#   'rx',
#   'refills',
#   'much',
#   'easier',
#   'telehealth'],
#  ['cdc',
#   'listed',
#   'following',
#   'top',
#   'conditions',
#   'contributing',
#   'deaths',
#   'covid',
#   '19',
#   'listed',
#   'death',
#   'certificate',
#   'influenza',
#   'pneumonia',
#   'respiratory',
#   'failure',
#   'hypertensive',
#   'disease',
#   'diabetes',
#   'vascular',
#   'unspecified',
#   'dementia',
#   'cgadamo',
#   'thebiglie'],
#  ['cdc',
#   'primary',
#   'causes',
#   'death',
#   'also',
#   'tested',
#   'covid',
#   'suspected',
#   'covid',
#   'accidental',
#   'deaths',
#   'suicide',
#   '5000',
#   'heart',
#   'attack',
#   '19500',
#   'dementia',
#   'alzheimers',
#   '23700',
#   'cancer',
#   '7000',
#   'sepsis',
#   '13200',
#   'stroke',
#   '7250',
#   'total',
#   '75650'],
#  ['counts',
#   'deaths',
#   'also',
#   'tested',
#   'suspected',
#   'covid',
#   'accidental',
#   'deaths',
#   'suicide5000',
#   'heart',
#   'attack19500',
#   'dementia',
#   'alzheimers23700',
#   'cancer7000',
#   'sepsis13200',
#   'stroke7250',
#   'total75650',
#   'covid19',
#   'coronavirus',
#   'covid',
#   'scamdemic2020'],
#  ['went',
#   'co',
#   'morbitiy',
#   'data',
#   'people',
#   'died',
#   'illness',
#   'also',
#   'confirmed',
#   'suspected',
#   'covid',
#   'accidental',
#   'deaths',
#   'suicide',
#   '5000',
#   'heart',
#   'attack',
#   '19500',
#   'dementia',
#   'alzheimers',
#   '23700',
#   'cancer',
#   '7000',
#   'sepsis',
#   '13200',
#   'stroke',
#   '7250',
#   'total',
#   '75650',
#   'covid19'],
#  ['ur',
#   'sheep',
#   'aunt',
#   'died',
#   'dementia',
#   'giving',
#   'months',
#   'live',
#   'prior',
#   'covid',
#   'died',
#   'tested',
#   'found',
#   'covid',
#   'listed',
#   'covid',
#   'death'],
#  ['sounds',
#   'like',
#   'one',
#   'reading',
#   'articles',
#   'covid',
#   'heart',
#   'disease',
#   '6k',
#   'deaths',
#   'obesity',
#   'ruled',
#   'covid',
#   'deaths',
#   '20k',
#   'dementia',
#   '25k',
#   'diabetes',
#   'admit',
#   'want',
#   'america',
#   'fall',
#   'democrats',
#   'chance',
#   'november'],
#  ['certainly',
#   'understand',
#   '94',
#   'year',
#   'old',
#   'fil',
#   'early',
#   'signs',
#   'dementia',
#   'repeats',
#   'lot',
#   'things',
#   'happy',
#   'listen',
#   'stories',
#   'growing',
#   'old',
#   'sucks',
#   'many',
#   'ways',
#   'especially',
#   'covid',
#   'loved',
#   'ones',
#   'us'],
#  ['hmm',
#   '180',
#   '000',
#   'covid_19',
#   'deaths',
#   'accurate',
#   'lives',
#   'back',
#   '90',
#   'deaths',
#   'related',
#   'hypertensive',
#   'disease',
#   'diabetes',
#   'vascular',
#   'dementia',
#   'cardiac',
#   'arrest',
#   'heart',
#   'failure',
#   'renal',
#   'failure',
#   'intentional',
#   'unintentional',
#   'injuries'],
#  ['find',
#   'state',
#   'rejected',
#   'death',
#   'certificate',
#   'dr',
#   'signature',
#   'legible',
#   'back',
#   'step',
#   'one',
#   'know',
#   'says',
#   'dementia',
#   'mention',
#   'covid',
#   'covid19',
#   'greatly',
#   'underreported',
#   'dementia',
#   'exasperated',
#   'covid',
#   'would',
#   'alive'],
#  ['covid',
#   'gives',
#   'influenza',
#   'chronic',
#   'respiratory',
#   'disease',
#   'circulatory',
#   'disease',
#   'heart',
#   'disease',
#   'heart',
#   'attack',
#   'arrhythmia',
#   'heart',
#   'failure',
#   'cerebrovascular',
#   'disease',
#   'sepsis',
#   'malignant',
#   'neoplasm',
#   'diabetes',
#   'obesity',
#   'alzheimers',
#   'vascular',
#   'dementia',
#   'renal',
#   'failure',
#   'poisoning'],
#  ['covid',
#   '19',
#   'stigma',
#   'scandalous',
#   'neglect',
#   'people',
#   'living',
#   'dementia',
#   'via',
#   'tc_africa'],
#  ['personally',
#   'know',
#   'three',
#   'deaths',
#   'listed',
#   'covid',
#   'families',
#   'went',
#   'fight',
#   'taken',
#   'death',
#   'certificate',
#   'one',
#   'died',
#   'heart',
#   'attack',
#   'one',
#   'motorcycle',
#   'accident',
#   'dementia',
#   'tell',
#   'something',
#   'right'],
#  ['people',
#   'still',
#   'dementia',
#   'dead',
#   'hermain',
#   'cain',
#   'ghost',
#   'account',
#   'tweeted',
#   'covid',
#   'fatal',
#   'someone',
#   'prolly',
#   'believes'],
#  ['please',
#   'pray',
#   'right',
#   'mother',
#   'fur',
#   'baby',
#   'dementia',
#   'forgets',
#   'everyone',
#   'name',
#   'last',
#   'days',
#   'decide',
#   'put',
#   'sleep',
#   'risk',
#   'getting',
#   'covid',
#   'passing',
#   'waiting',
#   'die',
#   'home'],
#  ['could',
#   'preexisting',
#   'covid',
#   'others',
#   'clearly',
#   'underlying',
#   'conditions',
#   'like',
#   'diabetes',
#   '26k',
#   'obesity',
#   '5614',
#   'alzheimer',
#   '5608',
#   'dementia',
#   '18',
#   '5k',
#   'still',
#   'others',
#   'apparently',
#   'deaths',
#   'covid',
#   'rather',
#   'accidents',
#   'suicides',
#   '5k'],
#  ['got',
#   'dementia',
#   'addled',
#   'head',
#   'cities',
#   'minorities',
#   'democrats',
#   'suffer',
#   'covid',
#   'thinks',
#   'advantage',
#   'livesdontmatter',
#   'winningisall'],
#  ['new',
#   'cdc',
#   'report',
#   'shows',
#   '94',
#   'covid',
#   '19',
#   'deaths',
#   'us',
#   'contributing',
#   'conditions',
#   'influenza',
#   'pneumonia',
#   'respiratory',
#   'failure',
#   'hypertensive',
#   'disease',
#   'diabetes',
#   'vascular',
#   'unspecified',
#   'dementia',
#   'cardiac',
#   'arrest',
#   'heart',
#   'failure',
#   'renal',
#   'failure'],
#  ['know',
#   'long',
#   'term',
#   'years',
#   'decades',
#   'effects',
#   'covid',
#   'people',
#   'polio',
#   'children',
#   'sequelae',
#   'old',
#   'age',
#   'covid',
#   'lead',
#   'say',
#   'early',
#   'kidney',
#   'failure',
#   'early',
#   'dementia',
#   'know',
#   'protect',
#   'everyone'],
#  ['ikr',
#   'make',
#   'matters',
#   'worse',
#   'every',
#   'time',
#   'sneeze',
#   'blow',
#   'stuffy',
#   'nose',
#   'hubby',
#   'freaks',
#   'one',
#   'thing',
#   'sunk',
#   'past',
#   'dementia',
#   'fear',
#   'covid',
#   'sneeze',
#   'get',
#   'sprayed',
#   'lysol',
#   'almost',
#   'funny',
#   'sneaks',
#   'sprays'],
#  ['covid',
#   '19',
#   'death',
#   'report',
#   'shows',
#   'open',
#   'america',
#   '94',
#   'covid',
#   '19',
#   'deaths',
#   'underlying',
#   'conditions',
#   'influenza',
#   'pneumonia',
#   'respiratory',
#   'failure',
#   'hypertensive',
#   'disease',
#   'diabetes',
#   'vascular',
#   'unspecified',
#   'dementia',
#   'underlying',
#   'condition',
#   'ok',
#   'open'],
#  ['add',
#   'esp',
#   'uk',
#   'deaths',
#   'recorded',
#   'causes',
#   'concrete',
#   'people',
#   'died',
#   'cancer',
#   'dementia',
#   'says',
#   'covid',
#   'see',
#   'past',
#   'bull',
#   'shit',
#   'mate'],
#  ['realise',
#   'dementia',
#   'weakens',
#   'immune',
#   'system',
#   'virus',
#   'like',
#   'covid',
#   'guaranteed',
#   'kill',
#   'also',
#   'realise',
#   'people',
#   'die',
#   'heart',
#   'failure',
#   'causes',
#   'via',
#   'covid',
#   'pneumonia',
#   'little',
#   'pusspuss',
#   'blocks',
#   'people',
#   'debunk',
#   'laughable',
#   'contexless',
#   'memes'],
#  ['eamonnholmes',
#   'ruthieel',
#   'watching',
#   'programme',
#   'thank',
#   'highlighting',
#   'care',
#   'homes',
#   '83',
#   'dementia',
#   'residents',
#   'evicted',
#   '30',
#   'oct',
#   'state',
#   'art',
#   'care',
#   'homes',
#   'liverpool',
#   '16',
#   'million',
#   'spent',
#   'open',
#   'homes',
#   'months',
#   'ago',
#   'closing',
#   'nothing',
#   'covid'],
#  ['totally',
#   'understand',
#   'mother',
#   'alzheimer',
#   'dementia',
#   'unfortunately',
#   'passed',
#   'away',
#   'covid',
#   '19',
#   'april',
#   'fortunate',
#   'support',
#   'shuhala',
#   'abbas',
#   'phone',
#   'need',
#   'bilingual',
#   'support',
#   'community'],
#  ['cdc',
#   'listed',
#   'following',
#   'top',
#   'conditions',
#   'contributing',
#   'deaths',
#   'involving',
#   'covid',
#   '19',
#   'influenza',
#   'pneumonia',
#   'respiratory',
#   'failure',
#   'hypertensive',
#   'disease',
#   'diabetes',
#   'vascular',
#   'unspecified',
#   'dementia',
#   'cont',
#   'article'],
#  ['nazia',
#   'meriyaadaincic',
#   'done',
#   'lot',
#   'smaller',
#   'local',
#   'neighbourhood',
#   'based',
#   'workshops',
#   'roadshows',
#   'yes',
#   'work',
#   'unfortunately',
#   'due',
#   'covid',
#   'restrictions',
#   'hard',
#   'support',
#   'bame',
#   'families',
#   'isolated',
#   'bacause',
#   'unsure',
#   'unabke',
#   'use',
#   'technology'],
#  ['goodmorning',
#   'load',
#   'breaks',
#   'way',
#   'carry',
#   'morethancare',
#   'elderly',
#   'elderlycare',
#   'seniorcare',
#   'healthcare',
#   'seniorliving',
#   'homecare',
#   'care',
#   'health',
#   'love',
#   'eldercare',
#   'dementia',
#   'family',
#   'caregiving',
#   'covid',
#   'caregiver',
#   'aging',
#   'dementiacare'],
#  ['dementia', 'covid', 'dolly', 'michelle', 'shillary'],
#  ['true',
#   'activities',
#   'director',
#   'long',
#   'term',
#   'care',
#   'facility',
#   'lost',
#   'patients',
#   'due',
#   'covid',
#   'however',
#   'dementia',
#   'patients',
#   'hit',
#   'hardest',
#   'understand',
#   'loved',
#   'ones',
#   'come',
#   'see',
#   'keep',
#   'asking',
#   'done',
#   'something',
#   'wrong'],
#  ['90',
#   'cvd19',
#   'mortalities',
#   'would',
#   'died',
#   'within',
#   'months',
#   'anyway',
#   'pre',
#   'existing',
#   'illnesses',
#   'average',
#   'age',
#   'covid',
#   'deceased',
#   'person',
#   '82',
#   '25',
#   'dementia',
#   'ward',
#   'residents'],
#  ['surgery',
#   '2019',
#   'hc',
#   'glucose',
#   'low',
#   'hc',
#   'save',
#   'fr',
#   'led',
#   'drug',
#   'war',
#   'inside',
#   'intravenous',
#   'insulin',
#   'injection',
#   'enemy',
#   'hospital',
#   'led',
#   'drug',
#   'war',
#   'effect',
#   'include',
#   'dementia',
#   'lost',
#   'memory',
#   'hc',
#   'recovery',
#   'amid',
#   'covid',
#   '19',
#   'drsanjaygupta',
#   'ac360',
#   'donlemon',
#   'halagorani',
#   'camanpour',
#   'cnni',
#   'cnn'],
#  ['sorry',
#   'cdc',
#   'adding',
#   'covid',
#   'one',
#   'dies',
#   'hospitals',
#   'get',
#   'money',
#   'motorcycle',
#   'accidents',
#   'covid',
#   'dementia',
#   'covid',
#   'old',
#   'age',
#   'covid',
#   'drug',
#   'overdoses',
#   'covid',
#   'heard',
#   'passed',
#   'cancer',
#   'yet',
#   'may',
#   'covid'],
#  ['lost',
#   'job',
#   'lost',
#   'loved',
#   'ones',
#   'contracted',
#   'disease',
#   'guess',
#   'virus',
#   'even',
#   'affect',
#   'died',
#   'dementia',
#   'around',
#   'time',
#   'got',
#   'still',
#   'counted',
#   'covid',
#   '19',
#   'death',
#   'liked',
#   'joke',
#   '180',
#   '000',
#   'knew'],
#  ['following',
#   'top',
#   'underlying',
#   'medical',
#   'conditions',
#   'linked',
#   'covid',
#   '19',
#   'deaths',
#   'influenza',
#   'pneumonia',
#   'respiratory',
#   'failure',
#   'hypertensive',
#   'disease',
#   'diabetes',
#   'vascular',
#   'unspecified',
#   'dementia',
#   'cardiac',
#   'arrest',
#   'heart',
#   'failure',
#   'renal',
#   'failure'],
#  ['know',
#   'anyone',
#   'risk',
#   'flu',
#   'pneumonia',
#   'respiratory',
#   'failure',
#   'hypertension',
#   'diabetes',
#   'vascular',
#   'unspecified',
#   'dementia',
#   'cardiac',
#   'arrest',
#   'heart',
#   'renal',
#   'failure',
#   'injury',
#   'poisoning',
#   'adverse',
#   'events',
#   'risk',
#   'covid',
#   'cause',
#   'celebrate',
#   'right'],
#  ['would',
#   'consequences',
#   'beyond',
#   'covid',
#   '19',
#   'allow',
#   'people',
#   'fall',
#   'cracks',
#   'would',
#   'mean',
#   'changing',
#   'coronal',
#   'legislation',
#   'would',
#   'skew',
#   'data',
#   'terrifying',
#   'degree',
#   'residential',
#   'care',
#   'provide',
#   'end',
#   'life',
#   'care',
#   'majority',
#   'deaths',
#   'due',
#   'dementia',
#   'frequent'],
#  ['9000',
#   'otherwise',
#   'healthy',
#   'people',
#   'underlying',
#   'conditions',
#   'died',
#   'concerning',
#   'others',
#   'still',
#   'died',
#   'covid',
#   'underlying',
#   'conditions',
#   'also',
#   'got',
#   'exacerbated',
#   'act',
#   'like',
#   'matter'],
#  ['aware',
#   'listing',
#   'diagnosis',
#   'covid',
#   'otherwise',
#   'healthy',
#   'people',
#   'without',
#   'underlying',
#   'conditions',
#   'rest',
#   'multiple',
#   'issues',
#   'likely',
#   'exacerbated',
#   'covid',
#   'copd',
#   'chf',
#   'covid',
#   'die',
#   'still',
#   'covid'],
#  ['true',
#   'nurse',
#   'would',
#   'ever',
#   'say',
#   'covid',
#   'attacked',
#   'dementia',
#   'true',
#   'would',
#   'already',
#   'studied',
#   'explicitly',
#   'continuing',
#   'research',
#   'sorry',
#   'heartache',
#   'may',
#   'pain',
#   'replaced',
#   'w',
#   'loving',
#   'smiles',
#   'good',
#   'memories',
#   'soon'],
#  ['precisely',
#   'patient',
#   'hiv',
#   'goes',
#   'hospital',
#   'develops',
#   'pneumonia',
#   'dies',
#   'patient',
#   'b',
#   'dementia',
#   '10',
#   'years',
#   'goes',
#   'hospital',
#   'develops',
#   'pneumonia',
#   'dies',
#   'pneumonia',
#   'listed',
#   'cause',
#   'death',
#   'either',
#   'patient',
#   'liberal',
#   'covid',
#   '19',
#   'reality',
#   'covid',
#   'killed'],
#  ['read',
#   'breakdown',
#   'comorbidities',
#   'also',
#   'includes',
#   'cancer',
#   'dementia',
#   'alzheimer',
#   'intentional',
#   'unintentional',
#   'injuries',
#   'poisonings',
#   'several',
#   'causes',
#   'death',
#   'covid',
#   'would',
#   'contributing',
#   'factor'],
#  ['stupid',
#   'reply',
#   'explain',
#   'respiratory',
#   'failure',
#   'respiratory',
#   'arrest',
#   'chronic',
#   'respiratory',
#   'disease',
#   'ards',
#   'cardiac',
#   'arrest',
#   'sepsis',
#   'alzheimer',
#   'dementia',
#   'renal',
#   'failure',
#   'covid',
#   'cause',
#   'deaths'],
#  ['smells',
#   'flavors',
#   'missing',
#   '95yr',
#   'old',
#   'mom',
#   'went',
#   'in2',
#   'nursing',
#   'home',
#   'dementia',
#   'covid',
#   'hit',
#   'takes',
#   'anymore',
#   'things',
#   'healthies',
#   'demanded',
#   'covid',
#   'stopped',
#   'move',
#   'slow',
#   'kinda',
#   'covid'],
#  ['18', '497', 'covid', 'deaths', 'vascular', 'unspecified', 'dementia'],
#  ['yes',
#   'go',
#   '5g',
#   'way',
#   'spread',
#   'covid',
#   'bodies',
#   'boys',
#   'sewage',
#   'system',
#   'melbourne',
#   'brigade',
#   'sam',
#   '78',
#   'cases',
#   'today',
#   'want',
#   'start',
#   'marches',
#   'street',
#   'thing',
#   'dementia',
#   'finally',
#   'got'],
#  ['ok',
#   'comorbidities',
#   'heart',
#   'attack',
#   'heart',
#   'failure',
#   'alzheimer',
#   'vascular',
#   'dementia',
#   'sepsis',
#   'renal',
#   'failure',
#   'intentional',
#   'unintentional',
#   'injury',
#   'poisoning',
#   'adverse',
#   'events',
#   'covid',
#   'least',
#   'worries'],
#  ...]

# %%
dictionary = corpora.Dictionary(texts)
dictionary
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-105-c59030b6f0a7> in <module>()
# ----> 1 dictionary = corpora.Dictionary(texts)
#       2 dictionary
#
# NameError: name 'corpora' is not defined
